# %%
# Python script to create a GitHub issue using the GitHub API
#
# Prerequisites:
# 1. A GitHub Personal Access Token (PAT) with 'repo' scope.
#    - You can create one here: https://github.com/settings/tokens
# 2. The 'requests' library installed.
#    - You can install it by running: pip install requests

import requests
import json

# --- CONFIGURATION ---
# Replace these placeholders with your actual data

# Your GitHub Personal Access Token. Keep this secret!
# It's best practice to load this from an environment variable or a secure vault.
GITHUB_TOKEN= 

# The owner of the repository (e.g., 'octocat')
REPO_OWNER = "aiopenscale"

# The name of the repository (e.g., 'Hello-World')
REPO_NAME = "aifs-documentation"

# Your GitHub Enterprise hostname. For example: 'github.yourcompany.com'
# If you are using public github.com, leave this as None.
GITHUB_HOSTNAME = "github.ibm.com" # e.g., "github.ibm.com"


def create_github_issue(title, body=None, assignees=None, labels=None):
    """
    Creates a new issue on a specified GitHub repository.

    Args:
        title (str): The title of the issue.
        body (str, optional): The contents of the issue. Defaults to None.
        assignees (list, optional): A list of GitHub usernames to assign to the issue.
                                    Defaults to None.
        labels (list, optional): A list of label names to add to the issue.
                                 Defaults to None.

    Returns:
        bool: True if the issue was created successfully, False otherwise.
    """
    # Construct the API URL based on whether a custom hostname is provided
    if GITHUB_HOSTNAME:
        # URL for GitHub Enterprise
        url = f"https://{GITHUB_HOSTNAME}/api/v3/repos/{REPO_OWNER}/{REPO_NAME}/issues"
    else:
        # URL for public GitHub
        url = f"https://api.github.com/repos/{REPO_OWNER}/{REPO_NAME}/issues"

    # Set up the headers for the API request, including authentication
    headers = {
        "Authorization": f"token {GITHUB_TOKEN}",
        "Accept": "application/vnd.github.v3+json",
    }

    # Create the data payload for the new issue
    data = {
        "title": title,
        "body": body,
        "assignees": assignees if assignees else [],
        "labels": labels if labels else []
    }

    print(f"Sending request to create issue: '{title}' at {url}")

    try:
        # Make the POST request to the GitHub API
        response = requests.post(url, data=json.dumps(data), headers=headers)

        # Raise an exception for bad status codes (4xx or 5xx)
        response.raise_for_status()

        # If the request was successful (status code 201 Created)
        response_data = response.json()
        print(f"✅ Successfully created issue #{response_data['number']}.")
        print(f"   View it here: {response_data['html_url']}")
        return True

    except requests.exceptions.RequestException as e:
        # Handle potential errors like network issues or invalid API responses
        print(f"❌ Error creating issue: {e}")
        # Print the response content for more detailed error info if available
        if 'response' in locals() and response.content:
            print(f"   Response from server: {response.text}")
        return False


# --- SCRIPT EXECUTION ---
if __name__ == "__main__":
    # Example usage of the function
    # Define the details for the new issue you want to create
    issue_title = "Factsheets (system facts and clones)"
    # issue_body = "This is a test issue created by a Python script. ✨\n\nWe can even include **markdown**!"
    # issue_assignees = []  # Optional: e.g., ["username1", "username2"]
    # issue_labels = ["bug", "automation"] # Optional: e.g., ["bug", "help wanted"]

    # Check if the configuration variables have been changed from placeholders
    if GITHUB_TOKEN == "YOUR_PERSONAL_ACCESS_TOKEN" or \
       REPO_OWNER == "YOUR_REPOSITORY_OWNER" or \
       REPO_NAME == "YOUR_REPOSITORY_NAME":
        print("⚠️  Please update the configuration variables (GITHUB_TOKEN, REPO_OWNER, REPO_NAME) at the top of the script.")
    else:
        # Call the function to create the issue
        create_github_issue(issue_title)
# Out:
# Sending request to create issue: 'Factsheets (system facts and clones)' at https://github.ibm.com/api/v3/repos/aiopenscale/aifs-documentation/issues
# ✅ Successfully created issue #23.
#    View it here: https://github.ibm.com/aiopenscale/aifs-documentation/issues/23

# %%
def get_api_base_url():
    """Constructs the base API URL."""
    if GITHUB_HOSTNAME:
        return f"https://{GITHUB_HOSTNAME}/api/v3"
    else:
        return "https://api.github.com"

def list_accessible_repos():
    """
    Lists all repositories accessible to the authenticated user.
    This includes public, private, and internal repositories.
    Handles pagination to retrieve all results.

    Returns:
        list: A list of repository full names (e.g., 'owner/repo'), or None if an error occurs.
    """
    repos_url = f"{get_api_base_url()}/user/repos"
    headers = {
        "Authorization": f"token {GITHUB_TOKEN}",
        "Accept": "application/vnd.github.v3+json",
    }
    params = {
        "per_page": 100, # Request the maximum number of items per page
    }
    
    all_repos = []
    url = repos_url

    print("Fetching accessible repositories...")

    try:
        while url:
            response = requests.get(url, headers=headers, params=params)
            response.raise_for_status()
            
            # Add the full names of the repos from the current page to our list
            repos_page = response.json()
            all_repos.extend([repo['full_name'] for repo in repos_page])
            
            # Check for the 'next' page link in the headers
            if 'next' in response.links:
                url = response.links['next']['url']
                # Params are included in the next URL, so we clear them for subsequent requests
                params = None 
            else:
                url = None # No more pages

        print(f"✅ Found {len(all_repos)} repositories.")
        return all_repos

    except requests.exceptions.RequestException as e:
        print(f"❌ Error listing repositories: {e}")
        if 'response' in locals() and response.content:
            print(f"   Response from server: {response.text}")
        return None

# %%
repo_list = list_accessible_repos()
# Out:
# Fetching accessible repositories...
# ✅ Found 313 repositories.

# %%
[i for i in repo_list if "aiopenscale" in i]
# Out:
# ['aiopenscale/ai-ops-squad-tests',
#  'aiopenscale/aiopenscale-broker',
#  'aiopenscale/aiopenscale-deployment',
#  'aiopenscale/aiopenscale-dev',
#  'aiopenscale/aiopenscale-monitoring',
#  'aiopenscale/aiopenscale-newrelic',
#  'aiopenscale/aiopenscale-scans',
#  'aiopenscale/aios-cloudant-backup',
#  'aiopenscale/aios-composite-service',
#  'aiopenscale/aios-configmaps',
#  'aiopenscale/aios-custom-engine',
#  'aiopenscale/aios-event-client-python',
#  'aiopenscale/aios-fvt',
#  'aiopenscale/aios-java-ubi-minimal-base',
#  'aiopenscale/aios-kpi-manager-service',
#  'aiopenscale/aios-liberty-base',
#  'aiopenscale/aios-messages',
#  'aiopenscale/aios-monitors',
#  'aiopenscale/aios-node-base',
#  'aiopenscale/aios-operations',
#  'aiopenscale/aios-orch-common-clients',
#  'aiopenscale/aios-orch-common-repos',
#  'aiopenscale/aios-orch-common-utils',
#  'aiopenscale/aios-payload-logging-spark',
#  'aiopenscale/aios-performance-test',
#  'aiopenscale/aios-python-base',
#  'aiopenscale/aios-python-ubi-minimal-base',
#  'aiopenscale/aios-scala-base',
#  'aiopenscale/AIOS-Scans',
#  'aiopenscale/aios-test-common',
#  'aiopenscale/aios-ubi8-minimal',
#  'aiopenscale/aios-ubi9-minimal',
#  'aiopenscale/aios-usage-service',
#  'aiopenscale/aios-webscan-scripts',
#  'aiopenscale/api-client-utils',
#  'aiopenscale/api-clients',
#  'aiopenscale/api-documentation',
#  'aiopenscale/assurance-monitor',
#  'aiopenscale/com.ibm.itest.cloud.aios.canvas',
#  'aiopenscale/com.ibm.itest.cloud.apsportal',
#  'aiopenscale/com.ibm.itest.cloud.common',
#  'aiopenscale/common-scoring-utils',
#  'aiopenscale/consumption-monitoring-tests',
#  'aiopenscale/correlations-framework',
#  'aiopenscale/cpd-fyre-cluster',
#  'aiopenscale/customers',
#  'aiopenscale/datamart-service-api-tests',
#  'aiopenscale/dev-testing-issues',
#  'aiopenscale/devops-parent',
#  'aiopenscale/ebtrack',
#  'aiopenscale/engg-dash',
#  'aiopenscale/git-duplicateissues-squadpred',
#  'aiopenscale/graphql-docs',
#  'aiopenscale/I-Q-team-repo',
#  'aiopenscale/I-Q-Team_tracker',
#  'aiopenscale/ibm-watson-openscale-bundle',
#  'aiopenscale/ibm-watson-openscale-operator',
#  'aiopenscale/icp-embedded-installer',
#  'aiopenscale/icp4ai-pipeline',
#  'aiopenscale/lime',
#  'aiopenscale/mcsp-ibmcloud',
#  'aiopenscale/metric-plugins',
#  'aiopenscale/migration-tool',
#  'aiopenscale/model-operation-CLI',
#  'aiopenscale/model-operation-tasks',
#  'aiopenscale/modelops-ui',
#  'aiopenscale/node-utils',
#  'aiopenscale/openscale-assistant-integration',
#  'aiopenscale/openscale-monitoring',
#  'aiopenscale/openscale-monitoring-log-parser',
#  'aiopenscale/payload-logging-knowledge-transfer',
#  'aiopenscale/performance-test-aiops',
#  'aiopenscale/project-overload',
#  'aiopenscale/sonarqube-automation',
#  'aiopenscale/sps-compliance-evidence',
#  'aiopenscale/sps-compliance-inventory',
#  'aiopenscale/sps-compliance-issues',
#  'aiopenscale/sps-security-scans-config',
#  'aiopenscale/testfest',
#  'aiopenscale/tracker',
#  'aiopenscale/watsonx-gov-beta-allowlist',
#  'aiopenscale/wml-metrics',
#  'aiopenscale/wos-compliance-evidence',
#  'aiopenscale/wos-compliance-inventory',
#  'aiopenscale/wos-compliance-issues',
#  'aiopenscale/wos-security',
#  'aiopenscale/wos-security-scans-config',
#  'aiopenscale/wos-spark-manager-api',
#  'aiopenscale/wos-support',
#  'aiopenscale/wos-synlab']

# %%
a = """Use cases <- anyone
Associating workspaces <- Shreya
Model Tracking mechanism  <- Femi
Models Promotion mechanism <-
Factsheet settings and the default inventory  <- Puneet
Attachments <- Ranjana
Reports and Report templates  <- Ranjana
Custom facts <- Ranjana
External models  <- Jinu/Femi
Openpages integration <- Deirdre
Multicluster support  <- Ranjana
Evaluation studio <- ShreyaFactsheets (system facts and clones) Jinu
Use cases <- anyone
Associating workspaces <- Shreya
Model Tracking mechanism  <- Femi
Models Promotion mechanism <-
Factsheet settings and the default inventory  <- Puneet
Attachments <- Ranjana
Reports and Report templates  <- Ranjana
Custom facts <- Ranjana
External models  <- Jinu/Femi
Openpages integration <- Deirdre
Multicluster support  <- Ranjana
Evaluation studio <- Shreya"""

# %%
a = a.split('\n')

# %%
temp = [i.split("<-")[0].strip() for i in a]

# %%
for i in tqdm(temp):
    body="""
    The expectation is to create a documentation page that any developer can use to understand and work on the above-mentioned feature.
    The document should contain information on the asset types used, the assets created, and the events that cause the asset to be modified. (if applicable)
    """
    create_github_issue(title=i, body=body)
# Out:
#   0%|                                                                                                                                                        | 0/24 [00:00<?, ?it/s]
# Sending request to create issue: 'Use cases' at https://github.ibm.com/api/v3/repos/aiopenscale/aifs-documentation/issues
#   4%|██████                                                                                                                                          | 1/24 [00:01<00:36,  1.57s/it]
# ✅ Successfully created issue #24.
#    View it here: https://github.ibm.com/aiopenscale/aifs-documentation/issues/24
# Sending request to create issue: 'Associating workspaces' at https://github.ibm.com/api/v3/repos/aiopenscale/aifs-documentation/issues
#   8%|████████████                                                                                                                                    | 2/24 [00:03<00:36,  1.64s/it]
# ✅ Successfully created issue #25.
#    View it here: https://github.ibm.com/aiopenscale/aifs-documentation/issues/25
# Sending request to create issue: 'Model Tracking mechanism' at https://github.ibm.com/api/v3/repos/aiopenscale/aifs-documentation/issues
#  12%|██████████████████                                                                                                                              | 3/24 [00:04<00:32,  1.56s/it]
# ✅ Successfully created issue #26.
#    View it here: https://github.ibm.com/aiopenscale/aifs-documentation/issues/26
# Sending request to create issue: 'Models Promotion mechanism' at https://github.ibm.com/api/v3/repos/aiopenscale/aifs-documentation/issues
#  17%|████████████████████████                                                                                                                        | 4/24 [00:06<00:33,  1.66s/it]
# ✅ Successfully created issue #27.
#    View it here: https://github.ibm.com/aiopenscale/aifs-documentation/issues/27
# Sending request to create issue: 'Factsheet settings and the default inventory' at https://github.ibm.com/api/v3/repos/aiopenscale/aifs-documentation/issues
#  21%|██████████████████████████████                                                                                                                  | 5/24 [00:08<00:31,  1.65s/it]
# ✅ Successfully created issue #28.
#    View it here: https://github.ibm.com/aiopenscale/aifs-documentation/issues/28
# Sending request to create issue: 'Attachments' at https://github.ibm.com/api/v3/repos/aiopenscale/aifs-documentation/issues
#  25%|████████████████████████████████████                                                                                                            | 6/24 [00:09<00:29,  1.65s/it]
# ✅ Successfully created issue #29.
#    View it here: https://github.ibm.com/aiopenscale/aifs-documentation/issues/29
# Sending request to create issue: 'Reports and Report templates' at https://github.ibm.com/api/v3/repos/aiopenscale/aifs-documentation/issues
#  29%|██████████████████████████████████████████                                                                                                      | 7/24 [00:11<00:28,  1.65s/it]
# ✅ Successfully created issue #30.
#    View it here: https://github.ibm.com/aiopenscale/aifs-documentation/issues/30
# Sending request to create issue: 'Custom facts' at https://github.ibm.com/api/v3/repos/aiopenscale/aifs-documentation/issues
#  33%|████████████████████████████████████████████████                                                                                                | 8/24 [00:13<00:26,  1.64s/it]
# ✅ Successfully created issue #31.
#    View it here: https://github.ibm.com/aiopenscale/aifs-documentation/issues/31
# Sending request to create issue: 'External models' at https://github.ibm.com/api/v3/repos/aiopenscale/aifs-documentation/issues
#  38%|██████████████████████████████████████████████████████                                                                                          | 9/24 [00:14<00:24,  1.65s/it]
# ✅ Successfully created issue #32.
#    View it here: https://github.ibm.com/aiopenscale/aifs-documentation/issues/32
# Sending request to create issue: 'Openpages integration' at https://github.ibm.com/api/v3/repos/aiopenscale/aifs-documentation/issues
#  42%|███████████████████████████████████████████████████████████▌                                                                                   | 10/24 [00:16<00:23,  1.70s/it]
# ✅ Successfully created issue #33.
#    View it here: https://github.ibm.com/aiopenscale/aifs-documentation/issues/33
# Sending request to create issue: 'Multicluster support' at https://github.ibm.com/api/v3/repos/aiopenscale/aifs-documentation/issues
#  46%|█████████████████████████████████████████████████████████████████▌                                                                             | 11/24 [00:18<00:22,  1.73s/it]
# ✅ Successfully created issue #34.
#    View it here: https://github.ibm.com/aiopenscale/aifs-documentation/issues/34
# Sending request to create issue: 'Evaluation studio' at https://github.ibm.com/api/v3/repos/aiopenscale/aifs-documentation/issues
#  50%|███████████████████████████████████████████████████████████████████████▌                                                                       | 12/24 [00:20<00:21,  1.78s/it]
# ✅ Successfully created issue #35.
#    View it here: https://github.ibm.com/aiopenscale/aifs-documentation/issues/35
# Sending request to create issue: 'Use cases' at https://github.ibm.com/api/v3/repos/aiopenscale/aifs-documentation/issues
#  54%|█████████████████████████████████████████████████████████████████████████████▍                                                                 | 13/24 [00:22<00:19,  1.79s/it]
# ✅ Successfully created issue #36.
#    View it here: https://github.ibm.com/aiopenscale/aifs-documentation/issues/36
# Sending request to create issue: 'Associating workspaces' at https://github.ibm.com/api/v3/repos/aiopenscale/aifs-documentation/issues
#  58%|███████████████████████████████████████████████████████████████████████████████████▍                                                           | 14/24 [00:23<00:17,  1.78s/it]
# ✅ Successfully created issue #37.
#    View it here: https://github.ibm.com/aiopenscale/aifs-documentation/issues/37
# Sending request to create issue: 'Model Tracking mechanism' at https://github.ibm.com/api/v3/repos/aiopenscale/aifs-documentation/issues
#  62%|█████████████████████████████████████████████████████████████████████████████████████████▍                                                     | 15/24 [00:25<00:16,  1.80s/it]
# ✅ Successfully created issue #38.
#    View it here: https://github.ibm.com/aiopenscale/aifs-documentation/issues/38
# Sending request to create issue: 'Models Promotion mechanism' at https://github.ibm.com/api/v3/repos/aiopenscale/aifs-documentation/issues
#  67%|███████████████████████████████████████████████████████████████████████████████████████████████▎                                               | 16/24 [00:27<00:14,  1.83s/it]
# ✅ Successfully created issue #39.
#    View it here: https://github.ibm.com/aiopenscale/aifs-documentation/issues/39
# Sending request to create issue: 'Factsheet settings and the default inventory' at https://github.ibm.com/api/v3/repos/aiopenscale/aifs-documentation/issues
#  71%|█████████████████████████████████████████████████████████████████████████████████████████████████████▎                                         | 17/24 [00:29<00:12,  1.80s/it]
# ✅ Successfully created issue #40.
#    View it here: https://github.ibm.com/aiopenscale/aifs-documentation/issues/40
# Sending request to create issue: 'Attachments' at https://github.ibm.com/api/v3/repos/aiopenscale/aifs-documentation/issues
#  75%|███████████████████████████████████████████████████████████████████████████████████████████████████████████▎                                   | 18/24 [00:31<00:10,  1.81s/it]
# ✅ Successfully created issue #41.
#    View it here: https://github.ibm.com/aiopenscale/aifs-documentation/issues/41
# Sending request to create issue: 'Reports and Report templates' at https://github.ibm.com/api/v3/repos/aiopenscale/aifs-documentation/issues
#  79%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏                             | 19/24 [00:32<00:09,  1.80s/it]
# ✅ Successfully created issue #42.
#    View it here: https://github.ibm.com/aiopenscale/aifs-documentation/issues/42
# Sending request to create issue: 'Custom facts' at https://github.ibm.com/api/v3/repos/aiopenscale/aifs-documentation/issues
#  83%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏                       | 20/24 [00:35<00:07,  1.88s/it]
# ✅ Successfully created issue #43.
#    View it here: https://github.ibm.com/aiopenscale/aifs-documentation/issues/43
# Sending request to create issue: 'External models' at https://github.ibm.com/api/v3/repos/aiopenscale/aifs-documentation/issues
#  88%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏                 | 21/24 [00:36<00:05,  1.87s/it]
# ✅ Successfully created issue #44.
#    View it here: https://github.ibm.com/aiopenscale/aifs-documentation/issues/44
# Sending request to create issue: 'Openpages integration' at https://github.ibm.com/api/v3/repos/aiopenscale/aifs-documentation/issues
#  92%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████            | 22/24 [00:38<00:03,  1.84s/it]
# ✅ Successfully created issue #45.
#    View it here: https://github.ibm.com/aiopenscale/aifs-documentation/issues/45
# Sending request to create issue: 'Multicluster support' at https://github.ibm.com/api/v3/repos/aiopenscale/aifs-documentation/issues
#  96%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████      | 23/24 [00:40<00:01,  1.87s/it]
# ✅ Successfully created issue #46.
#    View it here: https://github.ibm.com/aiopenscale/aifs-documentation/issues/46
# Sending request to create issue: 'Evaluation studio' at https://github.ibm.com/api/v3/repos/aiopenscale/aifs-documentation/issues
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 24/24 [00:42<00:00,  1.77s/it]
# ✅ Successfully created issue #47.
#    View it here: https://github.ibm.com/aiopenscale/aifs-documentation/issues/47

# %%
# !pip install tqdm
# Out:
# Collecting tqdm
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Installing collected packages: tqdm
# Successfully installed tqdm-4.67.1

# %%
from tqdm import tqdm

# %%
For prompts/detached PTA's in projects issue tracker is: https://github.ibm.com/dap/dap-planning/issues

For wml  and other models in projects tracker is: https://github.ibm.com/NGP-TWC/ml-planning/issues

For prompts/detached PTA's , wml and other models in spaces/deployments issue tracker is: https://github.ibm.com/NGP-TWC/ml-planning/issues

For issues related to OpenScale screen: https://github.ibm.com/aiopenscale/tracker/issues

# %%
# !pip install langchain langchain-openai pydantic
# Out:
# Collecting langchain
#   Downloading langchain-0.3.27-py3-none-any.whl.metadata (7.8 kB)
# Collecting langchain-openai
#   Downloading langchain_openai-0.3.29-py3-none-any.whl.metadata (2.4 kB)
# Collecting pydantic
#   Using cached pydantic-2.11.7-py3-none-any.whl.metadata (67 kB)
# Collecting langchain-core<1.0.0,>=0.3.72 (from langchain)
#   Downloading langchain_core-0.3.74-py3-none-any.whl.metadata (5.8 kB)
# Collecting langchain-text-splitters<1.0.0,>=0.3.9 (from langchain)
#   Downloading langchain_text_splitters-0.3.9-py3-none-any.whl.metadata (1.9 kB)
# Collecting langsmith>=0.1.17 (from langchain)
#   Downloading langsmith-0.4.13-py3-none-any.whl.metadata (14 kB)
# Collecting SQLAlchemy<3,>=1.4 (from langchain)
#   Downloading sqlalchemy-2.0.42-cp311-cp311-macosx_11_0_arm64.whl.metadata (9.6 kB)
# Requirement already satisfied: requests<3,>=2 in ./env/lib/python3.11/site-packages (from langchain) (2.32.4)
# Requirement already satisfied: PyYAML>=5.3 in ./env/lib/python3.11/site-packages (from langchain) (6.0.2)
# Collecting annotated-types>=0.6.0 (from pydantic)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.33.2 (from pydantic)
#   Using cached pydantic_core-2.33.2-cp311-cp311-macosx_11_0_arm64.whl.metadata (6.8 kB)
# Requirement already satisfied: typing-extensions>=4.12.2 in ./env/lib/python3.11/site-packages (from pydantic) (4.14.1)
# Collecting typing-inspection>=0.4.0 (from pydantic)
#   Using cached typing_inspection-0.4.1-py3-none-any.whl.metadata (2.6 kB)
# Collecting tenacity!=8.4.0,<10.0.0,>=8.1.0 (from langchain-core<1.0.0,>=0.3.72->langchain)
#   Using cached tenacity-9.1.2-py3-none-any.whl.metadata (1.2 kB)
# Collecting jsonpatch<2.0,>=1.33 (from langchain-core<1.0.0,>=0.3.72->langchain)
#   Using cached jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: packaging>=23.2 in ./env/lib/python3.11/site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (25.0)
# Requirement already satisfied: jsonpointer>=1.9 in ./env/lib/python3.11/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.72->langchain) (3.0.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./env/lib/python3.11/site-packages (from requests<3,>=2->langchain) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in ./env/lib/python3.11/site-packages (from requests<3,>=2->langchain) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./env/lib/python3.11/site-packages (from requests<3,>=2->langchain) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./env/lib/python3.11/site-packages (from requests<3,>=2->langchain) (2025.8.3)
# Collecting openai<2.0.0,>=1.86.0 (from langchain-openai)
#   Downloading openai-1.99.6-py3-none-any.whl.metadata (29 kB)
# Collecting tiktoken<1,>=0.7 (from langchain-openai)
#   Downloading tiktoken-0.11.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (6.7 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in ./env/lib/python3.11/site-packages (from openai<2.0.0,>=1.86.0->langchain-openai) (4.10.0)
# Collecting distro<2,>=1.7.0 (from openai<2.0.0,>=1.86.0->langchain-openai)
#   Using cached distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in ./env/lib/python3.11/site-packages (from openai<2.0.0,>=1.86.0->langchain-openai) (0.28.1)
# Collecting jiter<1,>=0.4.0 (from openai<2.0.0,>=1.86.0->langchain-openai)
#   Using cached jiter-0.10.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (5.2 kB)
# Requirement already satisfied: sniffio in ./env/lib/python3.11/site-packages (from openai<2.0.0,>=1.86.0->langchain-openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in ./env/lib/python3.11/site-packages (from openai<2.0.0,>=1.86.0->langchain-openai) (4.67.1)
# Requirement already satisfied: httpcore==1.* in ./env/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.86.0->langchain-openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in ./env/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<2.0.0,>=1.86.0->langchain-openai) (0.16.0)
# Collecting regex>=2022.1.18 (from tiktoken<1,>=0.7->langchain-openai)
#   Downloading regex-2025.7.34-cp311-cp311-macosx_11_0_arm64.whl.metadata (40 kB)
# Collecting orjson>=3.9.14 (from langsmith>=0.1.17->langchain)
#   Downloading orjson-3.11.1-cp311-cp311-macosx_15_0_arm64.whl.metadata (42 kB)
# Collecting requests-toolbelt>=1.0.0 (from langsmith>=0.1.17->langchain)
#   Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Collecting zstandard>=0.23.0 (from langsmith>=0.1.17->langchain)
#   Using cached zstandard-0.23.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (3.0 kB)
# Downloading langchain-0.3.27-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 17.3 MB/s  0:00:00
# Using cached pydantic-2.11.7-py3-none-any.whl (444 kB)
# Using cached pydantic_core-2.33.2-cp311-cp311-macosx_11_0_arm64.whl (1.9 MB)
# Downloading langchain_core-0.3.74-py3-none-any.whl (443 kB)
# Using cached jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Downloading langchain_text_splitters-0.3.9-py3-none-any.whl (33 kB)
# Downloading sqlalchemy-2.0.42-cp311-cp311-macosx_11_0_arm64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 16.3 MB/s  0:00:00
# Using cached tenacity-9.1.2-py3-none-any.whl (28 kB)
# Downloading langchain_openai-0.3.29-py3-none-any.whl (74 kB)
# Downloading openai-1.99.6-py3-none-any.whl (786 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 786.3/786.3 kB 10.8 MB/s  0:00:00
# Using cached distro-1.9.0-py3-none-any.whl (20 kB)
# Using cached jiter-0.10.0-cp311-cp311-macosx_11_0_arm64.whl (321 kB)
# Downloading tiktoken-0.11.0-cp311-cp311-macosx_11_0_arm64.whl (999 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 999.3/999.3 kB 10.6 MB/s  0:00:00
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading langsmith-0.4.13-py3-none-any.whl (372 kB)
# Downloading orjson-3.11.1-cp311-cp311-macosx_15_0_arm64.whl (129 kB)
# Downloading regex-2025.7.34-cp311-cp311-macosx_11_0_arm64.whl (285 kB)
# Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Using cached typing_inspection-0.4.1-py3-none-any.whl (14 kB)
# Using cached zstandard-0.23.0-cp311-cp311-macosx_11_0_arm64.whl (633 kB)
# Installing collected packages: zstandard, typing-inspection, tenacity, SQLAlchemy, regex, pydantic-core, orjson, jsonpatch, jiter, distro, annotated-types, tiktoken, requests-toolbelt, pydantic, openai, langsmith, langchain-core, langchain-text-splitters, langchain-openai, langchain
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20/20 [langchain] 19/20 [langchain]openai]
# Successfully installed SQLAlchemy-2.0.42 annotated-types-0.7.0 distro-1.9.0 jiter-0.10.0 jsonpatch-1.33 langchain-0.3.27 langchain-core-0.3.74 langchain-openai-0.3.29 langchain-text-splitters-0.3.9 langsmith-0.4.13 openai-1.99.6 orjson-3.11.1 pydantic-2.11.7 pydantic-core-2.33.2 regex-2025.7.34 requests-toolbelt-1.0.0 tenacity-9.1.2 tiktoken-0.11.0 typing-inspection-0.4.1 zstandard-0.23.0

# %%
import os
import getpass

if "OPENAI_API_KEY" not in os.environ:
    # Prompt for the key if it's not found in the environment
    api_key = getpass.getpass("OpenAI API Key not found. Please enter it here: ")
    os.environ["OPENAI_API_KEY"] = api_key
    print("✅ OpenAI API Key has been set for this session.")
else:
    # Acknowledge that the key is already set
    print("✅ OpenAI API Key is already set.")

# You can now safely use the key, for example:
# from openai import OpenAI
# client = OpenAI() # The client automatically reads the environment variable
# Out:
# ✅ OpenAI API Key is already set.

# %%
import os
from langchain_openai import ChatOpenAI
from langchain.prompts import PromptTemplate
from langchain_core.pydantic_v1 import BaseModel, Field

# --- 1. Your Repository Data ---
repo_list = [
    {
        "url": "https://github.ibm.com/dap/dap-planning/issues",
        "description": "For issues related to prompt template assets (PTA) and detached prompt template assets (DTPA) in a project."
    },
    {
        "url": "https://github.ibm.com/NGP-TWC/ml-planning/issues",
        "description": "For issues related to Watson Machine Learning (WML) models. Also for issues related to Deployment Spaces."
    },
    {
        "url": "https://github.ibm.com/aiopenscale/tracker/issues",
        "description": "For issues related to the evaluation of a model or PTA, or any issue related to the Openscale service."
    },
]

# --- 2. Define Your Desired Output Structure ---
# We want the LLM to return the URL of the chosen repository.
class RepoChoice(BaseModel):
    repo_url: str = Field(description="The URL of the single best repository for the issue.")

# --- 3. Format the Repository List for the Prompt ---
# We'll convert the list of dicts into a clean string for the LLM.
formatted_repos = "\n---\n".join([
    f"URL: {repo['url']}\nDescription: {repo['description']}" for repo in repo_list
])

# --- 4. Create the Prompt Template ---
prompt_template = PromptTemplate.from_template(
    """You are an expert at routing software engineering issues to the correct repository.
Based on the user's issue description, choose the single most appropriate repository from the list below.

Here are the available repositories and their descriptions:
{repos}

User's Issue:
"{user_issue}"

You must choose one repository.
"""
)

# --- 5. Set up the LLM and the Chain ---
# We initialize the LLM and bind our Pydantic class to it.
# This forces the LLM to return JSON that matches the RepoChoice structure.
llm = ChatOpenAI(model="gpt-4o", temperature=0)
structured_llm = llm.with_structured_output(RepoChoice)

# Create the full chain using LangChain Expression Language (LCEL)
chain = prompt_template | structured_llm

# --- 6. Run the Chain with Example Issues ---

print("--- Routing Examples ---")

# Example 1: Should go to dap-planning
issue_1 = "My PTA is failing to save and I'm getting a 500 error."
choice_1 = chain.invoke({"repos": formatted_repos, "user_issue": issue_1})
print(f"Issue: '{issue_1}'")
print(f"Chosen Repo URL: {choice_1.repo_url}\n")
# 

# Example 2: Should go to ml-planning
issue_2 = "The WML model deployment is stuck in the 'in progress' state in our deployment space."
choice_2 = chain.invoke({"repos": formatted_repos, "user_issue": issue_2})
print(f"Issue: '{issue_2}'")
print(f"Chosen Repo URL: {choice_2.repo_url}\n")

# Example 3: Should go to aiopenscale/tracker
issue_3 = "The Openscale service is not correctly evaluating the fairness score for my model."
choice_3 = chain.invoke({"repos": formatted_repos, "user_issue": issue_3})
print(f"Issue: '{issue_3}'")
print(f"Chosen Repo URL: {choice_3.repo_url}\n")
# Out:
# /Users/puneet/Documents/learn/github-issue-creator/env/lib/python3.11/site-packages/langchain_openai/chat_models/base.py:1893: UserWarning: Received a Pydantic BaseModel V1 schema. This is not supported by method="json_schema". Please use method="function_calling" or specify schema via JSON Schema or Pydantic V2 BaseModel. Overriding to method="function_calling".
#   warnings.warn(
# --- Routing Examples ---
# Issue: 'My PTA is failing to save and I'm getting a 500 error.'
# Chosen Repo URL: https://github.ibm.com/dap/dap-planning/issues
#
# Issue: 'The WML model deployment is stuck in the 'in progress' state in our deployment space.'
# Chosen Repo URL: https://github.ibm.com/NGP-TWC/ml-planning/issues
#
# Issue: 'The Openscale service is not correctly evaluating the fairness score for my model.'
# Chosen Repo URL: https://github.ibm.com/aiopenscale/tracker/issues

# %%
import os
from typing import Optional
from langchain_openai import ChatOpenAI
from langchain.prompts import PromptTemplate
from langchain_core.pydantic_v1 import BaseModel, Field

# Ensure your API key is available in the environment
# os.environ["OPENAI_API_KEY"] = "sk-..."

# --- 1. Updated List with Display Names and Usernames ---
valid_assignees = [
    {"displayName": "Anurag", "githubUsername": "anurag-gh"},
    {"displayName": "Priya", "githubUsername": "priya-dev"},
    {"displayName": "Mike", "githubUsername": "mike-ops"},
    {"displayName": "Sara", "githubUsername": "sara-ml"},
]

# --- 2. Define the Output Structure (No change needed) ---
class Assignee(BaseModel):
    """A model to hold the identified assignee's GitHub username."""
    github_username: Optional[str] = Field(
        default=None,
        description="The official GitHub username of the person mentioned."
    )

# --- 3. Set up the LLM and Chain ---
llm = ChatOpenAI(model="gpt-4o", temperature=0)
structured_llm = llm.with_structured_output(Assignee)

# Updated prompt to handle both name types
prompt_template = PromptTemplate.from_template(
    """You are an expert at parsing text to identify an issue's assignee.
Analyze the user's issue description below.

Your task is to identify if a person is mentioned and map them to their official GitHub username.
- You MUST ONLY choose from the following list of valid users.
- A user can be mentioned by their display name or their GitHub username.
- Your final output MUST be their official `githubUsername`.
- If no one from the list is mentioned, or if it's unclear, you must return a null value.

**Valid Users:**
{valid_users}

**User's Issue:**
"{user_issue}"
"""
)

# Create the full chain
chain = prompt_template | structured_llm

# --- 4. Run the Chain with New Examples ---

print("--- Assignee Detection Examples ---")
# Format the rich list of users for the prompt
valid_users_str = "\n".join(
    [f"- Name: {user['displayName']}, Username: {user['githubUsername']}" for user in valid_assignees]
)

# Example 1: A display name is used
issue_1 = "The new machine learning model isn't loading in the testing environment. Can Sara please take a look at this?"
result_1 = chain.invoke({"valid_users": valid_users_str, "user_issue": issue_1})
print(f"Issue: '{issue_1}'")
print(f"Identified Assignee: {result_1.github_username}\n")

# Example 2: A GitHub username is used
issue_2 = "The database migration script failed. This seems like a backend task for priya-dev."
result_2 = chain.invoke({"valid_users": valid_users_str, "user_issue": issue_2})
print(f"Issue: '{issue_2}'")
print(f"Identified Assignee: {result_2.github_username}\n")

# Example 3: No valid user is mentioned
issue_3 = "The main website is down! We need all hands on deck."
result_3 = chain.invoke({"valid_users": valid_users_str, "user_issue": issue_3})
print(f"Issue: '{issue_3}'")
print(f"Identified Assignee: {result_3.github_username}\n")

# %%
import os
import json
from typing import Optional
from langchain_openai import ChatOpenAI
from langchain.prompts import PromptTemplate
from langchain_core.pydantic_v1 import BaseModel, Field

# --- 1. SETUP & DATA ---
# Ensure your API key is available in the environment
# os.environ["OPENAI_API_KEY"] = "sk-..."

# Define your application's static context data
REPO_LIST = [
    {
        "url": "https://github.ibm.com/dap/dap-planning/issues",
        "description": "For issues related to prompt template assets (PTA) and detached prompt template assets (DTPA) in a project."
    },
    {
        "url": "https://github.ibm.com/NGP-TWC/ml-planning/issues",
        "description": "For issues related to Watson Machine Learning (WML) models. Also for issues related to Deployment Spaces."
    },
    {
        "url": "https://github.ibm.com/aiopenscale/tracker/issues",
        "description": "For issues related to the evaluation of a model or PTA, or any issue related to the Openscale service."
    },
]
VALID_ASSIGNEES = [
    {"displayName": "Anurag", "githubUsername": "anurag-gh"},
    {"displayName": "Priya", "githubUsername": "priya-dev"}
]

# --- 2. DEFINE THE UNIFIED OUTPUT SCHEMA ---
class FullIssueDraft(BaseModel):
    """A complete, structured draft of a Git issue."""
    repo_url: str = Field(..., description="The URL of the single best repository for the issue.")
    assignee_username: Optional[str] = Field(default=None, description="The official GitHub username of the person mentioned.")
    title: str = Field(..., description="A concise, descriptive title, prefixed with 'Bug:', 'Feature:', or 'Task:'.")
    body: str = Field(..., description="A detailed, Markdown-formatted body for the issue. For bugs, include steps to reproduce.")

# --- 3. THE INTERACTIVE DRAFTER CLASS ---
class IssueDrafter:
    def __init__(self):
        # Store the original request and the latest draft
        self.original_request: str = ""
        self.current_draft: Optional[FullIssueDraft] = None

        # Initialize the LLM. We use one LLM for both initial and refinement calls.
        llm = ChatOpenAI(model="gpt-4o", temperature=0)
        structured_llm = llm.with_structured_output(FullIssueDraft)

        # --- Chain for Initial Draft Generation ---
        initial_prompt = PromptTemplate.from_template(
            """You are an expert engineering assistant. Your task is to convert a user's raw text into a complete, structured Git issue draft.
            Analyze the user's request and fill in all fields: repo, assignee, title, and body.

            **Context - Repositories:**
            {valid_repos}

            **Context - Valid Assignees:**
            {valid_assignees}

            **User's Raw Request:**
            "{user_issue}"
            """
        )
        self.initial_chain = initial_prompt | structured_llm

        # --- Chain for Refining an Existing Draft ---
        refinement_prompt = PromptTemplate.from_template(
            """You are an AI assistant helping a user refine a Git issue draft.
            Your task is to modify the 'Current Draft' based on the 'User's Modification Request'.
            You must return a complete, updated draft in the exact same structured format.

            **Original User Request (for context):**
            {original_user_request}

            **Current Draft (in JSON format):**
            {current_draft_json}

            **User's Modification Request:**
            "{user_modification_request}"
            """
        )
        self.refinement_chain = refinement_prompt | structured_llm

        # Format context data once
        self.valid_repos_str = "\n".join([f"- {repo['url']}: {repo['description']}" for repo in REPO_LIST])
        self.valid_assignees_str = "\n".join([f"- {user['displayName']} ({user['githubUsername']})" for user in VALID_ASSIGNEES])

    def generate_initial_draft(self, user_request: str) -> FullIssueDraft:
        print("⚙️ Generating initial draft...")
        self.original_request = user_request
        self.current_draft = self.initial_chain.invoke({
            "user_issue": user_request,
            "valid_repos": self.valid_repos_str,
            "valid_assignees": self.valid_assignees_str
        })
        return self.current_draft

    def refine_draft(self, modification_request: str) -> FullIssueDraft:
        print(f"\n⚙️ Refining draft with request: '{modification_request}'...")
        if not self.current_draft:
            raise ValueError("An initial draft must be generated before it can be refined.")

        self.current_draft = self.refinement_chain.invoke({
            "original_user_request": self.original_request,
            "current_draft_json": self.current_draft.json(), # Serialize the current Pydantic object to a JSON string
            "user_modification_request": modification_request
        })
        return self.current_draft

# --- 4. DEMO OF THE WORKFLOW ---
def display_draft(draft_name: str, draft: FullIssueDraft):
    print(f"\n--- {draft_name} ---")
    print(f"Repository: {draft.repo_url}")
    print(f"Assignee:   {draft.assignee_username}")
    print(f"Title:      {draft.title}")
    print("\n--- Body ---\n" + draft.body)
    print("---------------------------------")

if __name__ == "__main__":
    drafter = IssueDrafter()

    # --- Step 1: User provides the initial description ---
    initial_description = "The PTA service is crashing when I try to save. Priya said she saw this too. It's a critical failure."
    first_draft = drafter.generate_initial_draft(initial_description)
    display_draft("DRAFT 1: INITIAL GENERATION", first_draft)
# Out:
# /Users/puneet/Documents/learn/github-issue-creator/env/lib/python3.11/site-packages/langchain_openai/chat_models/base.py:1893: UserWarning: Received a Pydantic BaseModel V1 schema. This is not supported by method="json_schema". Please use method="function_calling" or specify schema via JSON Schema or Pydantic V2 BaseModel. Overriding to method="function_calling".
#   warnings.warn(
# ⚙️ Generating initial draft...
#
# --- DRAFT 1: INITIAL GENERATION ---
# Repository: https://github.ibm.com/dap/dap-planning/issues
# Assignee:   priya-dev
# Title:      Bug: PTA Service Crashes on Save
#
# --- Body ---
# ### Description
# The Prompt Template Assets (PTA) service is experiencing a critical failure when attempting to save. This issue has been confirmed by multiple users.
#
# ### Steps to Reproduce
# 1. Open the PTA service.
# 2. Attempt to save any changes.
# 3. Observe the service crashing.
#
# ### Expected Behavior
# The service should save changes without crashing.
#
# ### Actual Behavior
# The service crashes upon attempting to save.
#
# ### Additional Information
# - This issue has been observed by Priya as well.
# - It is considered a critical failure and needs immediate attention.
# ---------------------------------

# %%
 # --- Step 2: User wants to modify the first draft ---
    modification_1 = "This is a blocker for the release. Please make the title more urgent and add that to the body."
    second_draft = drafter.refine_draft(modification_1)
    display_draft("DRAFT 2: AFTER FIRST REFINEMENT", second_draft)

    # --- Step 3: User wants to change the assignee ---
    modification_2 = "Actually, Anurag is the expert on the PTA service. Assign it to him instead."
    third_draft = drafter.refine_draft(modification_2)
    display_draft("DRAFT 3: AFTER SECOND REFINEMENT", third_draft)

# %%
import os
import sys
import requests

# --- Configuration ---
# Your GitHub Enterprise Personal Access Token (PAT)
# It's recommended to set this as an environment variable for security.
TOKEN = os.getenv('GITHUB_PAT')

# The specific API endpoint you provided.
API_URL = "https://github.ibm.com/api/v3/repos/wdp-gov/tracker/collaborators"

# --- Main Script ---

if not TOKEN:
    print("Error: GITHUB_TOKEN environment variable not set.")
    print("Please set your Personal Access Token as an environment variable.")
    # Exits the script if the token is not found.
    sys.exit(1)

# Standard headers for GitHub API requests
headers = {
    'Authorization': f'token {TOKEN}',
    'Accept': 'application/vnd.github.v3+json'
}

all_collaborators = []
url = API_URL

print(f"Fetching collaborators from {url}...")

try:
    # This loop will continue as long as a 'next' page URL is provided by the API.
    while url:
        response = requests.get(url, headers=headers)
        # Raises an exception for bad responses (4xx or 5xx)
        response.raise_for_status() 

        # Add the collaborators from the current page to our master list.
        all_collaborators.extend(response.json())

        # The 'requests' library handily parses the 'Link' header.
        # We look for the link to the 'next' page. If it doesn't exist, the loop ends.
        url = response.links.get('next', {}).get('url')
        if url:
            print("Fetching next page...")

    print("\n✅ Success! All collaborators have been fetched.")
    print(f"Total number of collaborators: {len(all_collaborators)}")

    # --- Display Results ---
    print("-" * 30)
    print("Username\t | Display Name")
    print("-" * 30)
    for user in all_collaborators:
        # The display name might be None if the user hasn't set one.
        display_name = user.get('name') if user.get('name') else "Not set"
        print(f"{user['login']:<15} | {display_name}")

except requests.exceptions.HTTPError as err:
    print(f"HTTP Error occurred: {err}")
    print(f"Status Code: {err.response.status_code}")
    print(f"Response: {err.response.text}")
except requests.exceptions.RequestException as err:
    print(f"An error occurred: {err}")
# Out:
# Fetching collaborators from https://github.ibm.com/api/v3/repos/wdp-gov/tracker/collaborators...
# Fetching next page...
# Fetching next page...
# Fetching next page...
# Fetching next page...
# Fetching next page...
# Fetching next page...
# Fetching next page...
# Fetching next page...
# Fetching next page...
# Fetching next page...
# Fetching next page...
# Fetching next page...
# Fetching next page...
# Fetching next page...
# Fetching next page...
# Fetching next page...
# Fetching next page...
# Fetching next page...
# Fetching next page...
# Fetching next page...
# Fetching next page...
# Fetching next page...
# Fetching next page...
# Fetching next page...
# Fetching next page...
# Fetching next page...
# Fetching next page...
# Fetching next page...
# Fetching next page...
# Fetching next page...
# Fetching next page...
# Fetching next page...
# Fetching next page...
# Fetching next page...
# Fetching next page...
# Fetching next page...
# Fetching next page...
# Fetching next page...
# Fetching next page...
# Fetching next page...
# Fetching next page...
# Fetching next page...
# Fetching next page...
# Fetching next page...
# Fetching next page...
# Fetching next page...
# Fetching next page...
# Fetching next page...
# Fetching next page...
# Fetching next page...
# Fetching next page...
# Fetching next page...
# Fetching next page...
# Fetching next page...
# Fetching next page...
#
# ✅ Success! All collaborators have been fetched.
# Total number of collaborators: 1654
# ------------------------------
# Username	 | Display Name
# ------------------------------
# dejan           | Not set
# Trent-Gray-Donald | Not set
# toeikmei        | Not set
# mpawlow         | Not set
# zhili           | Not set
# lsong           | Not set
# fding           | Not set
# azsong          | Not set
# maychu          | Not set
# lmlewis         | Not set
# shruthra        | Not set
# chrisj          | Not set
# julianpayne     | Not set
# hvetsa          | Not set
# gleong          | Not set
# miguelg         | Not set
# dvasilen        | Not set
# philipp-brucker | Not set
# frederic-pesquet | Not set
# kurapati        | Not set
# vivien          | Not set
# linju           | Not set
# mfriess         | Not set
# ROLWEBER        | Not set
# smc2            | Not set
# jbangs          | Not set
# Dino-Georgopoulos | Not set
# Michael-DuPlessis | Not set
# David-Doran     | Not set
# ROYTMAN         | Not set
# arnaud-schulz   | Not set
# amitd           | Not set
# Andrew-Allen    | Not set
# anhhong         | Not set
# tvasavi         | Not set
# gracelo         | Not set
# JSCHAECK        | Not set
# SERGEYKU        | Not set
# Jacinto-Carranco | Not set
# aparna          | Not set
# liw             | Not set
# Nigel-Terry     | Not set
# scdos           | Not set
# mwhoward        | Not set
# Greg-Lanthier   | Not set
# kwan            | Not set
# smadugun        | Not set
# jishuo          | Not set
# christian-fritsche | Not set
# Ken-Sparks      | Not set
# thollifi        | Not set
# Boris-Dachevski | Not set
# kozhaya         | Not set
# chrissie        | Not set
# rddesai         | Not set
# andreww         | Not set
# RONENKAT        | Not set
# shrinivas-kulkarni | Not set
# rpham           | Not set
# jayatheerthan   | Not set
# venkataramana-m | Not set
# MEHMETUE        | Not set
# thomas-cherel   | Not set
# SUHRE           | Not set
# FACTOR          | Not set
# sudhakarts      | Not set
# wangda          | Not set
# Vladimir-Vladimirov | Not set
# hemant-singh    | Not set
# kanellos        | Not set
# rajanikantapatnaik | Not set
# lwoolf          | Not set
# wfranke         | Not set
# saha-tapas      | Not set
# emmanuel-libert | Not set
# marion-bruells  | Not set
# PAULA           | Not set
# ddrouin         | Not set
# rsamal          | Not set
# piotrp          | Not set
# phillite        | Not set
# gupte           | Not set
# canhvu          | Not set
# antaiyab        | Not set
# vashisht        | Not set
# rpachipa        | Not set
# YSAILLET        | Not set
# crrenter        | Not set
# susanna-w-tai   | Not set
# mchowdh         | Not set
# gjadhava        | Not set
# gbramble        | Not set
# dmangin         | Not set
# subshekh        | Not set
# niraj           | Not set
# alamm           | Not set
# Tim-OFlynn      | Not set
# anjus           | Not set
# MARAMATI        | Not set
# slolvera        | Not set
# gvaradar        | Not set
# ACLIFFOR        | Not set
# rakharor        | Not set
# ROBKERN         | Not set
# Stephan-Laertz  | Not set
# ushakya         | Not set
# jsgray          | Not set
# Ghada-Obaid     | Not set
# Tom-Bentley     | Not set
# celek           | Not set
# ychien          | Not set
# sapnar          | Not set
# MOEHLER         | Not set
# anandi          | Not set
# PAR             | Not set
# svagaral        | Not set
# bharathreddym   | Not set
# payas-goyal     | Not set
# Suresh-Tirumalasetti | Not set
# nikhils         | Not set
# Andrzej-Wrobel  | Not set
# padkrish        | Not set
# dyarrang        | Not set
# syellare        | Not set
# ejacobso        | Not set
# sumit-kumar6    | Not set
# kbonagir        | Not set
# Lukasz-Cmielowski | Not set
# santkoth        | Not set
# sliddle         | Not set
# Klaus-Rindtorff | Not set
# Bartlomiej-Malecki | Not set
# shaithal        | Not set
# ERES            | Not set
# wojciech-sobala | Not set
# ayohannan       | Not set
# elainep         | Not set
# chiusm          | Not set
# hur             | Not set
# agarai          | Not set
# srinivas-pusapati | Not set
# yrayanki        | Not set
# Brennan-Fox     | Not set
# woodsja         | Not set
# yuanhsin-chen   | Not set
# markus-mueller  | Not set
# DIARFLYN        | Not set
# mundkur         | Not set
# vbmithun        | Not set
# rafal-bigaj     | Not set
# sshuklao        | Not set
# daniel-ryszka   | Not set
# ssundaram       | Not set
# chenxixi        | Not set
# snyk            | Not set
# ppadashe        | Not set
# Miriam-Guenther | Not set
# jinsalex        | Not set
# yuwang1         | Not set
# averma          | Not set
# samulowitz      | Not set
# boonema         | Not set
# sribhaum        | Not set
# sv-srinivas     | Not set
# guptaneeru      | Not set
# FUKUDAS         | Not set
# puhirema        | Not set
# tiwl            | Not set
# xiayue          | Not set
# mehboob         | Not set
# yyin            | Not set
# wenyi           | Not set
# averyw          | Not set
# mkashif         | Not set
# shyamalagowri   | Not set
# Danny-Xu        | Not set
# swami           | Not set
# ramvaddi        | Not set
# clang           | Not set
# emilyz          | Not set
# leticia         | Not set
# cou             | Not set
# otucker         | Not set
# madhusudankj    | Not set
# dili            | Not set
# namkabra        | Not set
# mrmadira        | Not set
# nickmazz        | Not set
# touma           | Not set
# raanei          | Not set
# TTAUCHI         | Not set
# rapentak        | Not set
# robincjose      | Not set
# SERSCH          | Not set
# ybopard         | Not set
# jnhagelberg     | Not set
# dawood          | Not set
# ravunoor        | Not set
# shahrokh        | Not set
# arsuryan        | Not set
# KABIS           | Not set
# kkarun          | Not set
# ORITP           | Not set
# smanick         | Not set
# cindyzh         | Not set
# cji             | Not set
# pkiran          | Not set
# xpu             | Not set
# SCHWARZT        | Not set
# afried1         | Not set
# sridharkuna     | Not set
# MOFFIE          | Not set
# kchik           | Not set
# ramana-krishnamshetty | Not set
# mtan            | Not set
# Michal-Zarakowski | Not set
# flachass        | Not set
# vpurand         | Not set
# dhanunjaya      | Not set
# electionreddy   | Not set
# ybjwang         | Not set
# HMTBR           | Not set
# ravi-tatapudi   | Not set
# LOUGHRAN        | Not set
# nmariyap        | Not set
# jspyker         | Not set
# SAYAKAF         | Not set
# tomasz-kania    | Not set
# khegarty        | Not set
# hupeng          | Not set
# ashwinir        | Not set
# wswitzer        | Not set
# sandra-belfils  | Not set
# Marek-Oszajec   | Not set
# prempiyush      | Not set
# dkantor         | Not set
# jhuo            | Not set
# sxguo           | Not set
# pauser          | Not set
# laxmi           | Not set
# vikasmahajan    | Not set
# sokollip        | Not set
# cmirash         | Not set
# grasselt        | Not set
# jaysen          | Not set
# andrew          | Not set
# KEIJIM          | Not set
# janani          | Not set
# neugebau        | Not set
# jdarosa         | Not set
# Thomas-Kolanko  | Not set
# jlimaye         | Not set
# vseth           | Not set
# dhmai           | Not set
# harikiran       | Not set
# svangara        | Not set
# arancha-ocana   | Not set
# mohd-omar       | Not set
# wasifk          | Not set
# saravind        | Not set
# jtsimis         | Not set
# benferna        | Not set
# kasia-gruszczynska | Not set
# jennalau        | Not set
# jsizto          | Not set
# msk             | Not set
# kanes           | Not set
# mottesen        | Not set
# FURS            | Not set
# KNISH           | Not set
# TAKEMAKI        | Not set
# Mark-Lewis      | Not set
# msjanapa        | Not set
# aaghaki         | Not set
# SAKURAB         | Not set
# POSULLIV        | Not set
# Mark-Balaban    | Not set
# arbrown         | Not set
# msrinivas       | Not set
# amelie-hocquette | Not set
# palkogan        | Not set
# sateesh-kolusu  | Not set
# baudelth        | Not set
# deepnaik        | Not set
# jcmamou         | Not set
# nandibhatla     | Not set
# kirajogu        | Not set
# nauvill         | Not set
# Raja-Sreekanth  | Not set
# Umit-Bektas     | Not set
# aseth011        | Not set
# spalani1        | Not set
# raolella        | Not set
# abdul-rawoof    | Not set
# dsnoddy         | Not set
# cpilar          | Not set
# sergiu          | Not set
# jennywu         | Not set
# SIMA            | Not set
# ravi-chamarthy  | Not set
# chaitanya-kumar | Not set
# shaertel        | Not set
# ahaldar         | Not set
# LBREMER         | Not set
# skambha         | Not set
# praveeth        | Not set
# ramakrishna-thota | Not set
# ssridhar        | Not set
# NICOLUSSI       | Not set
# ahmad-shafique  | Not set
# Michael-Rohr    | Not set
# mmkusum         | Not set
# surajpatel      | Not set
# msangine        | Not set
# GLOECK          | Not set
# mlewandowski    | Not set
# wojciech-wojcik | Not set
# sawyerst        | Not set
# Hans-Uhlig      | Not set
# muthukba        | Not set
# jjojo           | Not set
# jwcarman        | Not set
# Andrzej-Wieczorek | Not set
# Maciej-Sitarz   | Not set
# pkolosie        | Not set
# manfred-oevers  | Not set
# matthias-bierbrauer | Not set
# jaroslaw-jurowicz | Not set
# raghavendra-dhayapule | Not set
# rsalehin        | Not set
# osheat          | Not set
# leigh           | Not set
# TSHIMIZU        | Not set
# gururajarao     | Not set
# bkeach          | Not set
# Marcin-Luczynski | Not set
# KRudek          | Not set
# wingl           | Not set
# cmendonc        | Not set
# konstadin-langridge | Not set
# arya-adeli      | Not set
# Anu-Shaw        | Not set
# CORDULA         | Not set
# ekun            | Not set
# bfreund         | Not set
# madhurigorthi   | Not set
# tomasz-zatorski | Not set
# david-hay       | Not set
# holger-koenig   | Not set
# Paul-Kilroy     | Not set
# christophe-gefflot | Not set
# srinivas-vanka  | Not set
# sonashri        | Not set
# gonzaler        | Not set
# elainer         | Not set
# KMichal1        | Not set
# qilingc         | Not set
# lappanna        | Not set
# swapna-somineni | Not set
# yongli          | Not set
# jbamfor         | Not set
# Tomasz-Kazalski | Not set
# marcin-smetek   | Not set
# Pierre-Toussaint | Not set
# adam-bielak     | Not set
# Ricardo-Borba   | Not set
# amandapasquali  | Not set
# MFadel          | Not set
# simararneja     | Not set
# BRKINGST        | Not set
# ravigumm        | Not set
# jkeon           | Not set
# sorat           | Not set
# susancline      | Not set
# rbreno          | Not set
# padmagvs        | Not set
# sneeraj         | Not set
# gerrit          | Not set
# pierre-viricel  | Not set
# ecokorji        | Not set
# Brian-Freedman  | Not set
# NUNANDES        | Not set
# florence-varignier | Not set
# izuzu           | Not set
# Obidul-Islam    | Not set
# weiren          | Not set
# charekc         | Not set
# alan1           | Not set
# scheruku-in     | Not set
# nicolas-cominetti | Not set
# shuklash        | Not set
# rohit-viswanath | Not set
# aditi-sharma    | Not set
# anilkumart      | Not set
# rcadierno       | Not set
# amit-mathur     | Not set
# NITZSCHE        | Not set
# joanna-janusz   | Not set
# hughesg         | Not set
# saranyad        | Not set
# GREGORM         | Not set
# jwhyman         | Not set
# prasak12        | Not set
# MUHAFEEZ        | Not set
# hyungk          | Not set
# kgile           | Not set
# geethareddy     | Not set
# Yan-Shein       | Not set
# ZOR             | Not set
# carol-odonohoe  | Not set
# UETSUKI         | Not set
# savikash        | Not set
# ramychil        | Not set
# StefanGru       | Not set
# C-EW2U897       | Not set
# nagnarla        | Not set
# prasanth        | Not set
# DOERRE          | Not set
# unai-mayo       | Not set
# acoady          | Not set
# ewa-burda       | Not set
# rwdukes         | Not set
# FTERUI          | Not set
# STOEFF          | Not set
# Greg-McDonald   | Not set
# skvarada        | Not set
# syamprasad-d    | Not set
# ashrinid        | Not set
# bartlomiej-filipek | Not set
# UNIBOT          | Not set
# alauddin        | Not set
# sjikim          | Not set
# niall-jordan    | Not set
# David-Cummings  | Not set
# Christina-Fong  | Not set
# rajevemu        | Not set
# Marc-Cassagnol  | Not set
# MARCHAND        | Not set
# Mary-O-Neill    | Not set
# Shannon-Tang    | Not set
# michaela        | Not set
# bkdevara        | Not set
# leongm          | Not set
# geonchoi        | Not set
# rgoyette        | Not set
# diego-casaretti | Not set
# Artur-Gruszecki | Not set
# Bill-Guigue     | Not set
# prashsh1        | Not set
# teenamathew     | Not set
# DHOFF           | Not set
# Rafal-Korczyk   | Not set
# vekushwa        | Not set
# Bill-Theocharoulas | Not set
# Inbar-Shapira   | Not set
# afizshaik       | Not set
# Anindita-Mozumder1 | Not set
# Van-Zhou        | Not set
# pganapa1        | Not set
# Jerry-Chan      | Not set
# yamini-danthuluri | Not set
# srinivma        | Not set
# sswarna         | Not set
# Richard-Tang    | Not set
# mjayapa         | Not set
# Ian-Henderson   | Not set
# Carol-Wiest     | Not set
# Igor-Kozine     | Not set
# NTAKAYA         | Not set
# Jeff-Elliott    | Not set
# Suzie-Gareau    | Not set
# Rami-Nassif     | Not set
# kranthi-medisetti | Not set
# challa-harish   | Not set
# TSUGIURA        | Not set
# HATIF           | Not set
# SCHLIEPK        | Not set
# asangadi        | Not set
# Lukasz-Debiec1  | Not set
# madhaviibm      | Not set
# arnajdas        | Not set
# MAK0702         | Not set
# francisco-cano  | Not set
# Sachin-Prasad1  | Not set
# mhickok         | Not set
# sajajula        | Not set
# chouston        | Not set
# bharath         | Not set
# trudy           | Not set
# Vladimir-Kim    | Not set
# rajm            | Not set
# weiwei-liu10    | Not set
# Priyanka-Nayek1 | Not set
# sanjitc         | Not set
# lconrioux       | Not set
# Kian-Goh        | Not set
# sbakhtiy        | Not set
# sradapal        | Not set
# JOHNMATT        | Not set
# Jakub-Rachwalik1 | Not set
# pawel-wnek      | Not set
# Sammy-Schuckert | Not set
# George-Xu       | Not set
# anna-bogusz     | Not set
# venkatreddyg    | Not set
# pascal-lacombe  | Not set
# Dawn-N-Ahukanna | Not set
# Xiao-Chen       | Not set
# WKEESE          | Not set
# rayapati        | Not set
# dlprodsl        | Not set
# swatinanda      | Not set
# Stephanie-Valarezo1 | Not set
# yevgeniy-marchenko | Not set
# Michal-Bodziony | Not set
# kakavenkat      | Not set
# przemyslaw-szamraj | Not set
# egorelen        | Not set
# jamesc1         | Not set
# jgaonar         | Not set
# kmccarth        | Not set
# jfengsun        | Not set
# Heqin-Wang      | Not set
# kavbiswa        | Not set
# nbalaba         | Not set
# zhao            | Not set
# Dave-Reich      | Not set
# rambkare        | Not set
# tamara-tatian   | Not set
# Nigel-Campbell  | Not set
# REHFUSS         | Not set
# emily-chan      | Not set
# atanases        | Not set
# chudanie        | Not set
# MASAKOA         | Not set
# yogesh-agnihotri | Not set
# Roger-Keillor   | Not set
# vince-jm        | Not set
# daniel-suski    | Not set
# Maggie-Songge   | Not set
# michaela-regecova | Not set
# lukasz-palus    | Not set
# rhartmann       | Not set
# cvu             | Not set
# tim-horstkotte  | Not set
# Shalisha-Witherspoon | Not set
# Angad-Singh3    | Not set
# priyau          | Not set
# Krishna-Sheth   | Not set
# Justin-Yan      | Not set
# Celine-Goyette  | Not set
# amankum9        | Not set
# shneeraj        | Not set
# Benjamin-Hu     | Not set
# pooja-k-shah    | Not set
# gkhooks         | Not set
# Frederic-MIGNOT | Not set
# Vaishnavi-Gondane | Not set
# Derek-Lawless   | Not set
# ger-cunningham  | Not set
# delhoume        | Not set
# smwilkos        | Not set
# KOHLMANN-de     | Not set
# kaza-sudheer    | Not set
# srmitta         | Not set
# krirajpu        | Not set
# anvivyas        | Not set
# pgoyal89        | Not set
# fabrice-georges | Not set
# ISC-KRK-ISC-KRK | Not set
# chenzhan        | Not set
# snowdev         | Not set
# Varinder-Singh-Grewal | Not set
# phcheruk        | Not set
# Jean-Bergeron   | Not set
# Zina-Al-Sabbagh | Not set
# apahaadm        | Not set
# HIRORING        | Not set
# maria-oleszkiewicz | Not set
# larry-bakun     | Not set
# aliad           | Not set
# vemuriki        | Not set
# lena-eckstein   | Not set
# iautoma1        | Not set
# SYURIKO         | Not set
# yuebiao-ma      | Not set
# venkatarra      | Not set
# bjhala          | Not set
# vfalguera       | Not set
# iautoma2        | Not set
# Tiffany-Y-Li    | Not set
# Jan-Hassel      | Not set
# sandrat         | Not set
# angel-smith     | Not set
# CHARMAN         | Not set
# Zhibo-Zhang     | Not set
# rkulkund        | Not set
# gpatkoor        | Not set
# Henk-Cazemier   | Not set
# smarudai        | Not set
# clviana         | Not set
# David-Yuen      | Not set
# binojjacob      | Not set
# lwidjojo        | Not set
# lady-dayo       | Not set
# Asif-Saleh      | Not set
# adam-nowotarski | Not set
# Sunny-S-Patel   | Not set
# catui1          | Not set
# Dennis-Windsor  | Not set
# bbaskara        | Not set
# rui-mourao      | Not set
# IKAI            | Not set
# kkcharuk        | Not set
# susan-cotter    | Not set
# SOHDA           | Not set
# swpadala        | Not set
# subhak77        | Not set
# gkoumi          | Not set
# srux            | Not set
# T-Hanusiak      | Not set
# prasad-pechetty | Not set
# Rachel-Miles    | Not set
# Nipun-Bayas     | Not set
# TAKUK           | Not set
# myerragu        | Not set
# mkumar4n        | Not set
# mshaik          | Not set
# victoria-rickmann | Not set
# lwang           | Not set
# Jaehee-Lee1     | Not set
# Briana-S-Walker | Not set
# Akira-Fujiu     | Not set
# braganza        | Not set
# kksrishva       | Not set
# sukyim          | Not set
# Arkadiusz-Prusak | Not set
# kaohashi        | Not set
# Frederic-Delaroche | Not set
# camdfp          | Not set
# decimelli       | Not set
# MAEDERA         | Not set
# Joshua-Abraham  | Not set
# pjiang          | Not set
# Paulina-Chamczyk | Not set
# vbashyam-us     | Not set
# julian-solano   | Not set
# Jakub-Moor      | Not set
# jzheng-ca       | Not set
# rashmib2        | Not set
# tfreund         | Not set
# Shahrukh-Suhail | Not set
# Ganmani-Sekar   | Not set
# Georgina-Kinge  | Not set
# kevinyan        | Not set
# Mateusz-Kwarciak | Not set
# Satya-Prakash-Modi | Not set
# Robert-McAuley  | Not set
# Ashley-Bock     | Not set
# sravut86        | Not set
# Arif-Ege-Or     | Not set
# max-ibm         | Not set
# Christopher-Tokar | Not set
# Kevin-Lichen-Chu | Not set
# Ewa-Gardzielewska | Not set
# dpsts           | Not set
# Daniel-Wiesek   | Not set
# aiosdev         | Not set
# meghadarshanur  | Not set
# Marcin-Motyka   | Not set
# Pratyoosh-Kumar1 | Not set
# Manpreet-Bhamra | Not set
# SNOGAMI         | Not set
# JIENAN-WANG     | Not set
# Szczepan-Motyka | Not set
# HACHI           | Not set
# Tulika-Sahu     | Not set
# Angel-Lopez-Alegria1 | Not set
# Michael-Daschner | Not set
# Dmitriy-Drinfeld | Not set
# jshi            | Not set
# Tyler-Philips   | Not set
# ashwin-umathay  | Not set
# alekhya-telekicherla1 | Not set
# madhugan        | Not set
# bharraj1        | Not set
# Zhaoliang-Ding  | Not set
# Rasika-Guru     | Not set
# Katarzyna-Markiewicz | Not set
# Hemanth-Babu    | Not set
# vcholle1        | Not set
# dongm           | Not set
# Amritha-Herle   | Not set
# femi            | Not set
# shruthi-jain    | Not set
# Erin-Cornett    | Not set
# jacek-midura    | Not set
# Christopher-Alfonso | Not set
# Akash-Lakshman  | Not set
# Ammu-Soni       | Not set
# tami-jp         | Not set
# Zofia-Mazur     | Not set
# ugiaudit        | Not set
# pponduru        | Not set
# y-yang          | Not set
# Akinobu-Morishima | Not set
# Hiroki-Watanabe1 | Not set
# Victor-Lara     | Not set
# Baraa-Abdelsalam | Not set
# Gustavo-Murcia  | Not set
# Sagar-Thomas    | Not set
# David-Wan       | Not set
# Andreas-Reich   | Not set
# sgonsal         | Not set
# Vikram-Bhat1    | Not set
# stevenh         | Not set
# pravesh-ibm     | Not set
# Sean-Kong       | Not set
# Immalla-Chen    | Not set
# Gene-Azad       | Not set
# Shubham-Kale    | Not set
# Sanika-Tamhane  | Not set
# mtan-ibm        | Not set
# Christy-Hammill | Not set
# riskuma1        | Not set
# mkandiah-ibm    | Not set
# Anna-Cichos     | Not set
# Julia-Blyumen   | Not set
# Alan-Tran       | Not set
# divyag2         | Not set
# Akhil-Desai     | Not set
# Jonathan-Bruckbauer | Not set
# Kamil-Huras1    | Not set
# ryan-sciampacone-ibm | Not set
# srashmi         | Not set
# cp4d-perf       | Not set
# Mateusz-Tokarz1 | Not set
# Marcin-Baszak1  | Not set
# David-Vyvyan    | Not set
# Bharath-Kumar-Mankina | Not set
# kareng          | Not set
# bff             | Not set
# Klara-Nartowska1 | Not set
# Krzysztof-Wcislo | Not set
# Felix-Ba        | Not set
# ishaan-patel    | Not set
# Anna-Urban3     | Not set
# Anna-Migas      | Not set
# Jakub-Faliszewski | Not set
# DANIEL-KLAHN    | Not set
# Barry-Squire    | Not set
# wat4all         | Not set
# Siyu-Zhou       | Not set
# vakatima        | Not set
# Mengying-Yu     | Not set
# Jennifer-Hale   | Not set
# Gregoire-Cattan | Not set
# Andy-Lac        | Not set
# amir-sanjar     | Not set
# Michal-Fabrycy  | Not set
# pbting          | Not set
# Yuki-Sakata     | Not set
# Michiko-Tazawa  | Not set
# Nick-Gagan      | Not set
# Oliver-Kauselmann | Not set
# uzairchudhary   | Not set
# Dimitrios-Giannos | Not set
# atp-us          | Not set
# ananyasa        | Not set
# Tobias-Albrecht | Not set
# finley22        | Not set
# gagopi54        | Not set
# umindagu        | Not set
# pakhigupta      | Not set
# jcosta          | Not set
# Nerkunam-Venkatesh | Not set
# Shrinidhi-Kulkarni | Not set
# WKCUniScan-SaaSID | Not set
# Jacob-Stellon   | Not set
# ktaylor         | Not set
# bkduncan        | Not set
# cp4dsre         | Not set
# SBUBE           | Not set
# WKC-Term-Assignment-Service | Not set
# dsusbld         | Not set
# rshekatk        | Not set
# CeemaRajith     | Not set
# vivekrathi      | Not set
# Mengning-Yang   | Not set
# Zahra-Jalia     | Not set
# Peter-Mansour   | Not set
# AndresI         | Not set
# christine-sun   | Not set
# gzahavi         | Not set
# Kun-Lu          | Not set
# saraelsh        | Not set
# jamiehar        | Not set
# Emily-Garverick | Not set
# Mateusz-Bieda1  | Not set
# Jakub-Popardowski | Not set
# Natalia-Szczepanska | Not set
# Marwa-Nawabi    | Not set
# Mohammad-Nassar | Not set
# auto-bot        | Not set
# Mateusz-Hejzner | Not set
# Nirnayak-Bhardwaj | Not set
# bhavasha        | Not set
# Sylwia-Solecka  | Not set
# Wiktor-Wlecial  | Not set
# snimgaonkar     | Not set
# Dorota-Laczak   | Not set
# Wojciech-Krakowiak | Not set
# Grzegorz-Przybycien1 | Not set
# Matthew-Thompson | Not set
# chloe-maceda    | Not set
# Piotr-Rachwalik | Not set
# Javier-De-Rada-Torrado | Not set
# Lavanya-Nili    | Not set
# austin-ibm      | Not set
# Michael-Dobson  | Not set
# Jorie-Noll      | Not set
# sunny-dhawan    | Not set
# Kowshiga-Nanthakumar | Not set
# Ashwini-Rawat1  | Not set
# Joseph-Marenin  | Not set
# jonathan-lai    | Not set
# Michal-Szylar   | Not set
# Luis-Gomez      | Not set
# Nancy-Shen      | Not set
# Rachna-Jain2    | Not set
# Gunasekaran-Venkatesan | Not set
# AKANKSHA-Kumari4 | Not set
# Rajesh-kumar-Jayapal | Not set
# Muhammed-Abdul-Majeed-Ameen | Not set
# Francisco-Becker | Not set
# savin-ps        | Not set
# Shubham-Jaiswal4 | Not set
# Deirdre-Moran   | Not set
# Ranjana-V       | Not set
# Sanjam-Dahiya   | Not set
# Darsan-S        | Not set
# Michael-Mahmood | Not set
# denis-medeiros  | Not set
# Surinder-Kaur   | Not set
# Common-CICD-for-CPP | Not set
# Amit-Kumar90    | Not set
# ksadagopan-ibm  | Not set
# Madhusudan-Kumar | Not set
# Satwinder-Singh1 | Not set
# Satheeshkumar-Devarajan | Not set
# HARIS-M-U       | Not set
# jibina-sunny    | Not set
# Pauline-Chan    | Not set
# Amna-Jamal      | Not set
# Itai-Guez       | Not set
# Ben-Clermont    | Not set
# jesus-rocha     | Not set
# Bijoy-Thanikkal | Not set
# Mohamed-Mahameed | Not set
# Debasish-Parida | Not set
# Chandini-Jose   | Not set
# emilychan       | Not set
# Ashraf-Moideen  | Not set
# Latha-Naganna1  | Not set
# Jubin-Thomas    | Not set
# Pankaj-Thakur2  | Not set
# adrian-lee-ibm  | Not set
# Payal-Sharma1   | Not set
# Athanasios-Zorbas | Not set
# Sreelakshmi-R   | Not set
# Nishanth-Damodharan | Not set
# Lawrence-Luo    | Not set
# secinfra        | Not set
# Christopher-Giardina | Not set
# nandana         | Not set
# Saurabh-Kaushik1 | Not set
# Ryley-Wells     | Not set
# Ranjithkumar-Pandiyan | Not set
# Manjot-Sidhu    | Not set
# Vaibhav-Bhadade | Not set
# Akhil-V         | Not set
# Kwai-Fan-Lau    | Not set
# Upasana-Bhattacharya1 | Not set
# Valen-Mascarenhas | Not set
# Anand-Sasikumar | Not set
# Pyae-Hlian-Moe  | Not set
# David-Noecker   | Not set
# Thejaswini-K-S  | Not set
# Noel-Vincent    | Not set
# keita-nagaoka   | Not set
# m-harrigan      | Not set
# Tristian-Labanowich | Not set
# Nicole-Rabjohn  | Not set
# Chen-Yang-Chou  | Not set
# Kevin-Quinn     | Not set
# Harshit-Pandey  | Not set
# stevenz         | Not set
# Afsal-Pulukool  | Not set
# Sahil-Berwal    | Not set
# Ebin-Varghese   | Not set
# c3cvn9tx        | Not set
# Yussuf-Shaikh1  | Not set
# Vijay-Kumar24   | Not set
# geetha-pulipaty | Not set
# Laila-Goubran   | Not set
# Sophie-Jin      | Not set
# Paul-Moothedan  | Not set
# Geethu-P-Mohan  | Not set
# Shweta-Gharshi1 | Not set
# Shiju-John1     | Not set
# Anil-G1         | Not set
# Sandhya-Srikumar | Not set
# Ohad-Eytan1     | Not set
# AMRITA-J1       | Not set
# Abdul-Rauf-Kuzhiyancheri | Not set
# A-Praveen       | Not set
# Kavya-Prem      | Not set
# SNEHA-SNEHA7    | Not set
# Rehana-K-C1     | Not set
# Anjali-Dileepkumar1 | Not set
# Gowri-Sankar-P2 | Not set
# Gloria-Thomas1  | Not set
# Sidharth-P-B1   | Not set
# Riya-George     | Not set
# Kruti-Fadadu    | Not set
# Renju-R-S1      | Not set
# DAVID-HOANG001  | Not set
# Rahul-Surendran | Not set
# Joseph-Cherian  | Not set
# Megha-Varshney  | Not set
# Abdulla-Thanseeh | Not set
# Salil-Jain      | Not set
# Martin-Oberhofer | Not set
# Seema-Bhat      | Not set
# Or-Shefi        | Not set
# JASWANTH-CHERUKURI1 | Not set
# Githin-Joseph   | Not set
# Geethanjali-MR  | Not set
# Harishma-P      | Not set
# Nidhi-Perti     | Not set
# Siddesh-Sangodkar1 | Not set
# aminabou        | Not set
# Smitha-T-M1     | Not set
# Ravi-Panamana   | Not set
# Michael-Gelfand | Not set
# Sanjit-Raghavan | Not set
# shreya-sisodia  | Not set
# Thara-Basheer   | Not set
# Adarsh-k-s      | Not set
# Sonal-Mahambrey1 | Not set
# Greeshma-Rajendran | Not set
# Divya-K5        | Not set
# Maritta-Stephen | Not set
# remya-p         | Not set
# Vasudev-Chavan1 | Not set
# Arun-V-Ramesh   | Not set
# Narayanan-V-Eswar | Not set
# HARISH-PANAKKAL | Not set
# Hariprasath-Venkatachalapathi | Not set
# Anu-Antony2     | Not set
# Hariharan-Ashokan | Not set
# Samson-P-Mathew | Not set
# Thomas-Gimmy    | Not set
# Prachi-Kurade1  | Not set
# sergio-roncero  | Not set
# DENCY-P-DANIEL  | Not set
# Yevgeny-Zaligan | Not set
# bentonyjoe      | Not set
# BINDHU-SOMANPILLAI | Not set
# Somesh-Lad      | Not set
# dushyant-dave   | Not set
# michalwojtowicz | Not set
# Karolina-Szykula1 | Not set
# Christian-Bialek1 | Not set
# Anisha-Bandaram | Not set
# Suraj-Sethi     | Not set
# Jeff-Wai        | Not set
# Shelby-Fink     | Not set
# Luca-Stangohr   | Not set
# piotr-pasternak | Not set
# UST-Automation  | Not set
# Thasfeela-C-K   | Not set
# Pavitra-Modi    | Not set
# Julani-Summers  | Not set
# Retwick-Rajeevan | Not set
# magabriela-jimenez-aguilar | Not set
# Ethan-Zhang     | Not set
# Shanmugapriya-N | Not set
# Yuhan-Shao1     | Not set
# Jordan-Zetala   | Not set
# Ashwin-Kumar6   | Not set
# Vishnu-Pullat1  | Not set
# Anurag-Mohanty3 | Not set
# Serhii-Halkovskyi | Not set
# vikrant-sangwan | Not set
# Reetika-Agrawal | Not set
# Gagan-Kukkar    | Not set
# Akhil-Jonnalagadda | Not set
# Sunidhi-Thakker | Not set
# Aarush-Singh    | Not set
# Naveen-Nitturu  | Not set
# Elbin-Pallimalil | Not set
# jaswanth-pallavolu1 | Not set
# Anoop-Raj-B     | Not set
# aman-Varma      | Not set
# Abinav-Anil     | Not set
# Ethan-Wu        | Not set
# Arun-Nair2      | Not set
# Alif-Mohammed   | Not set
# Laukesh-Yadav   | Not set
# Sean-Cawley     | Not set
# Manavesh-N      | Not set
# Prabhu-Nair     | Not set
# Narayanan-T-K   | Not set
# Sruthi-K3       | Not set
# Soumya-P-Sawkar1 | Not set
# SIDDARTH-AJAY   | Not set
# raki-ibm        | Not set
# Ashna-A-N       | Not set
# Pranith-Rao     | Not set
# Keerti-Vanalli  | Not set
# Mayooran-Thavajogarasa | Not set
# Nick-FUNG       | Not set
# Suraj-Kumar24   | Not set
# amos-ibm        | Not set
# Michal-Steczko  | Not set
# Anton-Polozhii  | Not set
# jakub-walaszczyk | Not set
# Joel-Eapen-Varghese1 | Not set
# N-Rahul2        | Not set
# helen-ibm       | Not set
# SusanPhilip     | Not set
# Prashant-R-Harugade | Not set
# elysepeng       | Not set
# Anagha-Vijayan  | Not set
# aryapmohan      | Not set
# Ivan-Mamichau   | Not set
# Bhavna-Janardanan | Not set
# Nabeel-Siddiqui | Not set
# Aman-Puranik    | Not set
# Rituraj-Jha     | Not set
# NIMIYA-ANGEL1   | Not set
# UST-Security-Infrastructure-4 | Not set
# Harshit-Gupta4  | Not set
# Sonal-Bansal    | Not set
# Pawan-Kalligudda | Not set
# PeterHuang      | Not set
# Sreepriya-M     | Not set
# Sidharthakumar-S | Not set
# Daniyal-Mustafa1 | Not set
# Wojciech-Rebisz | Not set
# Ankur-Singh15   | Not set
# Praveen-Kumbar  | Not set
# Shreya-Narayanan | Not set
# KUSHAL-AGRAWAL  | Not set
# Suneesh-M-Suresh | Not set
# vishnu-sekhar   | Not set
# Madhu-Kalapala  | Not set
# Yaswitha-Chalichalamala | Not set
# SaiNathMekala22 | Not set
# Hari-Gopinathan | Not set
# Geethu-Girish   | Not set
# Xiaowei-Huang   | Not set
# V-S-JYOTHIRMAYE-PAGOTI | Not set
# Hemant-Revankar | Not set
# Girik-Prabhakar | Not set
# Mynhardt-Burger | Not set
# puneet          | Not set
# shurvir         | Not set
# Vandana-Shenoy1 | Not set
# Lakshmi-Narayanan2 | Not set
# Ajay-Sharma9    | Not set
# Anoop-V-S       | Not set
# Jakub-Filip     | Not set
# Anudeep-Dunaboyina | Not set
# ebaatarsuren    | Not set
# aruntv          | Not set
# Harish-R13      | Not set
# Edwin-Sagayaraj | Not set
# arie-pratama-s  | Not set
# Krishna-S       | Not set
# michael-adlung  | Not set
# Sravya-Sangineni | Not set
# Vishnu-Premkumar | Not set
# Jinu-Shaji      | Not set
# allwinchrisj    | Not set
# gururaj-naik    | Not set
# JUBIT-JOY       | Not set
# Joby-Chacko     | Not set
# Sushovan-Chatterjee1 | Not set
# Dorin-Jose      | Not set
# Jusdeep-Dhaliwal | Not set
# Esha-Nazrin1    | Not set
# Gokul-N-B       | Not set
# MannyLemos      | Not set
# Avi-Soni        | Not set
# anilkumar-ibm   | Not set
# Michal-Zych     | Not set
# agata-orminska  | Not set
# Mohak-Gemini    | Not set
# Renu-Rajagopal  | Not set
# Hemant-Marve    | Not set
# Tetiana-Shcherbak | Not set
# Shivang-Passawala | Not set
# marta-tomzik    | Not set
# shyamkrishna    | Not set
# atul-karn       | Not set
# ABHISHEK-M-U    | Not set
# Jaydeep-Sonawane | Not set
# Vasavi-Simma    | Not set
# Prabhjot-Kaur   | Not set
# dwwatson        | Not set
# Frederico-Alves | Not set
# akhil-gnair     | Not set
# Neaam-Hariri    | Not set
# Puskar-Thakur   | Not set
# mohammednavas-op | Not set
# joe-veliyath    | Not set
# filip-komarzyniec | Not set
# Wojciech-Kolarczyk | Not set
# alves-miguel    | Not set
# jmoravec        | Not set
# Jiri-Tousek     | Not set
# Ambika-Yernallikar | Not set
# Michael-Ys-Won  | Not set
# BhanuVamsiPriya | Not set
# Hanan-Cherian   | Not set
# Gautam-Kumar-J  | Not set
# joao-lourenco   | Not set
# glima           | Not set
# Vinitha-Palanethra1 | Not set
# Sujith-P-S      | Not set
# Anish-Mathew-Albert | Not set
# Muhammed-Ashiqu-K | Not set
# Akhilkumar-S    | Not set
# Abhay-Raj2      | Not set
# Amrutha-Polu    | Not set
# Sheshnarayan-Agrawal2 | Not set
# milin-ann-john  | Not set
# Yashwanth-Krishnan | Not set
# sreejith        | Not set
# Sarp-Arslan     | Not set
# Sanu-Ashok      | Not set
# hussain-abuwala | Not set
# Jamille-Ni      | Not set
# Arjoo-Patel     | Not set
# Chethana-MS     | Not set
# Patryk-Pierzchala1 | Not set
# Aleksandra-Liszka | Not set
# maciej-stokfisz | Not set
# Jakub-Ziemianski1 | Not set
# herman-lazarchyk | Not set
# beatrice-ibm    | Not set
# liuljun-ibm     | Not set
# Apeksha-Ananthakrishna | Not set
# Prince-Chauhan  | Not set
# Hrithik-Kumar-Verma | Not set
# v-jahnavi8790   | Not set
# Dmytro-Stonaiev | Not set
# Ondrej-Mazanec  | Not set
# Alexandre-Sa    | Not set
# mirzazackariakz | Not set
# lukashermann    | Not set
# William-Carey-Marlapudi | Not set
# rameshkannas    | Not set
# Pundaleek-Navale | Not set
# kumar-akshay    | Not set
# Teja-Kothapalli | Not set
# Ankit-Thakur3   | Not set
# RAGHAV-GOYAL    | Not set
# Anand-Prabhu1   | Not set
# Ramsushil-Jajee | Not set
# Ananya-Thapliyal | Not set
# Dharshini-V-J   | Not set
# Krishnadas-N    | Not set
# Mritunjay-Mohitesh | Not set
# Chamarthi-Vijaya-Lakshmi | Not set
# LESLIE-RODRIGUEZ | Not set
# akhilkakani     | Not set
# Mirza-Abdul-Gani-Baig | Not set
# Jithin-Jose     | Not set
# Syamrag-Ashokan | Not set
# Arvind-Radhakrishnan1 | Not set
# Srijan-Singh1   | Not set
# Vishnu-K2       | Not set
# Kurian-Kevin    | Not set
# Petr-Wudi       | Not set
# Lukas-Riedel    | Not set
# Roman-Kuraev    | Not set
# joao-mateus-ibm | Not set
# Fabio-Falcao    | Not set
# Jadir-Sousa     | Not set
# GabrielPereira  | Not set
# Vishnun         | Not set
# Mateusz-Paszek  | Not set
# jan-adamski     | Not set
# Jakub-Sitnik    | Not set
# Mikalai-Povarau | Not set
# Ilyas-Ilyasau   | Not set
# Adrian-Wojciak  | Not set
# Swadesh-Hede    | Not set
# Anurag-Dwivedi  | Not set
# Resat-Ozkurt    | Not set
# Katarzyna-Koczurek | Not set
# michal-kapitonow | Not set
# Arathi-Nair     | Not set
# garby           | Not set
# sreeraj-rajan   | Not set
# myrzatay-turarov | Not set
# marek-zuwala    | Not set
# mikolaj-mus     | Not set
# Sai-Sri-Vinay-Reddy-Sangam | Not set
# Yuriy-Serdyuk   | Not set
# Eli-Carter      | Not set
# Dishant-Chawla  | Not set
# Ajmal-Jamal     | Not set
# Obili-Umamaheswari | Not set
# Jan-Ulrych      | Not set
# Sumangala-Palled | Not set
# soban-farhan    | Not set
# Jan-Travnicek   | Not set
# Jacob-Knarr     | Not set
# Ayush-Gupta14   | Not set
# Shaik-Mohammed-Irfan-Saeed | Not set
# Sanchit-Rote    | Not set
# Josef-Kumstyr   | Not set
# Petr-Kosvanec   | Not set
# Michal-Podrabsky | Not set
# vojtechfric     | Not set
# jmartins-ibm    | Not set
# Andrei-Dodonov  | Not set
# m-tomasek       | Not set
# alexyin         | Not set
# Radek-Macha     | Not set
# Pradeep-Gowdru  | Not set
# Sachin-Kulkarni6 | Not set
# Lucie-Svitakova | Not set
# Crystal-Menezes | Not set
# Sarka-Kratochvilova | Not set
# Antony-C-S      | Not set
# Oldrich-Nouza   | Not set
# Jan-Dudek       | Not set
# Pallav-Walavalkar1 | Not set
# Neobuild        | Not set
# Shyam-Bhaskaran | Not set
# Karthika-Suresh | Not set
# hpipeln         | Not set
# Revathy-P       | Not set
# Indhu-Priya     | Not set
# liang-ibm       | Not set
# DIGNA-JAMES1    | Not set
# Vishwas-Balakrishna | Not set
# Argi-Candri     | Not set
# Caroline-Fahrenkrog | Not set
# Yevhen-Kotelnykov | Not set
# Abhishek-Anil   | Not set
# akhil-kp        | Not set
# Girish-Kunchanur | Not set
# Mert-Cetin      | Not set
# Batuhan-Kadioglu | Not set
# Adrian-Ostromecki | Not set
# rushabh-s       | Not set
# Xinyi-Huang     | Not set
# Francisco-Fernandes | Not set
# kiranraj        | Not set
# mabsolon        | Not set
# Denys-Filippov  | Not set
# dineshkumar-bhardwaj | Not set
# Jozef-Bugos     | Not set
# ktrzaska        | Not set
# Suryakanta-Samal | Not set
# Shivani-Mahavratayajula | Not set
# Kalu-Szymczak   | Not set
# Thang-Nguyen    | Not set
# Shireen-Khan    | Not set
# Sofia-Sampaio   | Not set
# Safuvan-K-P     | Not set
# BharathKumar-Cherukuri | Not set
# hlnguyen        | Not set
# sjn             | Not set
# luis-obregon    | Not set
# Anubhi-Golechha | Not set
# Lithin-Purushothaman | Not set
# SAJIKUMAR-JS    | Not set
# Alessandra-Nercolini | Not set
# Gabriel-Pereyra | Not set
# Jan-Zak         | Not set
# Sthuthi-Ghosh   | Not set
# mayouni         | Not set
# Peter-Mikulec   | Not set
# Goncalo-Mendes  | Not set
# Jan-Havlicek1   | Not set
# alanbeas        | Not set
# Hongwei-Jia     | Not set
# Pavel-Mrazek    | Not set
# David-Bucek     | Not set
# Sai-tumuluri    | Not set
# aravind-nk      | Not set
# Yadhukrishnan-K-U | Not set
# venktesh2002    | Not set
# Ankita-Munshi   | Not set
# pedro-ribeiro-ibm | Not set
# rbarros-ibm     | Not set
# Jaroslav-Kotrc  | Not set
# Vaclav-Lunak    | Not set
# Manish-Soni3    | Not set
# Maksim-Halubouski | Not set
# Anuroop-Prakash | Not set
# James-Zou       | Not set
# Raghavi-Kannan  | Not set
# Alex-Mohylevskyi | Not set
# bhagyashree-bhoyar | Not set
# Pedro-Faria     | Not set
# harish-kolenchery | Not set
# Michal-Bartos   | Not set
# greeshma-gopi   | Not set
# Anna-Lisowska   | Not set
# Katarzyna-Lipowska1 | Not set
# josue-monge     | Not set
# Robin-rvm       | Not set
# Tharik-Azees    | Not set
# AmanSingh       | Not set
# Hudson-Dye      | Not set
# Harikrishnan-M  | Not set
# Ajith-Mohan     | Not set
# Shanet-Mathew   | Not set
# Rinshad-Koissan | Not set
# neha-v          | Not set
# nithinxavier    | Not set
# rinkal-mehta    | Not set
# vigvargu        | Not set
# MichaelFan      | Not set
# Kimira-Tarra    | Not set
# Sankar-K        | Not set
# qiangjia-ibm    | Not set
# liuybo-ibm      | Not set
# weixing         | Not set
# ShuaiZhang      | Not set
# davidzhang-ibm  | Not set
# Venkatesh-H-S1  | Not set
# shwjin-ibm      | Not set
# JAYESH-v        | Not set
# Ragesh-C-K      | Not set
# Melissa-Fernandes | Not set
# Anoopa-Davis    | Not set
# msajadh         | Not set
# Faiz-Dani       | Not set
# Michal-Kyjovsky | Not set
# Bartlomiej-Szymanski | Not set
# Jakub-Kobialka1 | Not set
# Yuriy           | Not set
# Zain-Khan1      | Not set
# Dawid-Urbanik   | Not set
# vignesh-gopan   | Not set
# Victor-Segura   | Not set
# Arun-K-Balakrishnan | Not set
# Alia-Alsheha    | Not set
# Zuzanna-Jarlaczynska | Not set
# prince96        | Not set
# Nikita-George   | Not set
# rickyly         | Not set
# Aaron-Varghese  | Not set
# Raneeth-S8      | Not set
# Joe-Chmielewski | Not set
# piragathi-ashokan | Not set
# Santha-Ramala   | Not set
# Shashank-Bhushan-Jha | Not set
# ashlin-jerson   | Not set
# Sumi-Mathew     | Not set
# Selva-Kumar-Jothi-Arumugam | Not set
# Deepak-Palazhy  | Not set
# Hema-Haridas    | Not set
# Ahmed-Alsinan   | Not set
# alias-jacob     | Not set
# carlos-mspqa    | Not set
# FlaviaSilva     | Not set
# Bhushan-Mehendale | Not set
# Malshalaan      | Not set
# vijay-ps        | Not set
# Anju-Raveendran | Not set
# konrad-duleba   | Not set
# jan-kovarik     | Not set
# Robin-Jain1     | Not set
# Anne-McCormick  | Not set
# YangYang        | Not set
# lmendes         | Not set
# Md-Intekhab-Shaukat | Not set
# Mesih-Tasci     | Not set
# Jithin-Kumar    | Not set
# Alabiad-Hazem   | Not set
# Ali-Aldobyan    | Not set
# Vincenzo-Schifano | Not set
# Bhargavi-Gurram | Not set
# Thomas-Sanjurjo | Not set
# Ryan-Dalton     | Not set
# lijomv          | Not set
# Kotla-Santhosh  | Not set
# Ofreishdeep-Talwar | Not set
# xawyong-ibm     | Not set
# sabrina-li      | Not set
# Anup-Varma      | Not set
# Burak-Ugar      | Not set
# Daniel-Gonzalez-Lemus | Not set
# Keith-Costigan1 | Not set
# adit-ratnam     | Not set
# Shahim-S        | Not set
# Braham-Parkash  | Not set
# Bartlomiej-Chwast | Not set
# Artem-Kurov     | Not set
# Afonso-Fernandes | Not set
# Raviraj-Indraganti | Not set
# Alex-Sanchez-Cabana | Not set
# Maria-Vila-Abad | Not set
# Bartlomiej-Starzyk | Not set
# Yevgeniy-Lapko2 | Not set
# Kacper-Cwiertnia | Not set
# vladislav-nikolov-ibm | Not set
# Aleksandra-Sliwska | Not set
# Drew-Nutall-Smith | Not set
# Vipin-LV        | Not set
# Muhammad-Talha-Zulfiqar | Not set
# sathwika-yekula | Not set
# Sai-Vamsi-Yelamanchili1 | Not set
# D-ADARSHA-BHAT1 | Not set
# ananjay-gurjar  | Not set
# Daniel-Walters  | Not set
# Vartika-Koli    | Not set
# Sai-Mahidhar1   | Not set
# Rucha-Sohoni    | Not set
# Ryan-James      | Not set
# AMarshall-Fazio | Not set
# dimpulreddy-vankireddy | Not set
# Eddie-Park      | Not set
# Wxgfs1          | Not set
# Susannah-Medley | Not set
# Darren-Lo       | Not set
# Lee-Curtis      | Not set
# Mary-Sandra-Shibu | Not set
# Shubham-Gorai   | Not set
# bhavyapanchakarla | Not set
# Aldrin-Dennis1  | Not set
# thomas-jerard   | Not set
# Rachel-Hogan    | Not set
# Nayana-Madappattil | Not set
# Cassia-Fraga    | Not set
# Sunayana-Bandi  | Not set
# Martin-Gargalovic1 | Not set
# wojtek-kramarz  | Not set
# Gayathri-Nair1  | Not set
# Ashok-Somasundaram | Not set
# Duncan-Brown2   | Not set
# IBM-SWG-GHE     | Not set
# adityars        | Not set
# mithilakudalkar | Not set
# xiaoling-yang   | Not set
# Ishika-Soni     | Not set
# Yurii-Plakhtii  | Not set
# Anitha-Thiyagarajan | Not set
# Adinadh-Somepalli | Not set
# Samuel-Meyer    | Not set
# Siddhesh-Sharma1 | Not set
# Jaiganesh-Pasupathi | Not set
# AVXER4744       | Not set
# Farners-Vallespi-i-Soro | Not set
# Akshay-Gogeri   | Not set
# ShubhamGovindprasad-Sarda | Not set
# Amal-Alahmadi   | Not set
# filip-zmijewski | Not set
# Ievgenii-Iegorushkov | Not set
# Karol-Zmorski   | Not set
# Prakash-Palaniappan1 | Not set
# Vaibhav-Khandelwal1 | Not set
# Ikcsps          | Not set
# Zoe-Moniz       | Not set
# martin-mihaylov | Not set
# Svetoslav-Varbanov | Not set
# Kusum-Kumari4   | Not set
# Katasre1        | Not set
# Annu-Joseph     | Not set
# VINEETH-VIJAYAN2 | Not set
# nayana-as       | Not set
# Sruthy-P        | Not set
# esyed           | Not set
# Nihar-Dudam1    | Not set
# Michal-Polinski | Not set
# Pawel-Tympalski | Not set
# Krzysztof-Wysocki1 | Not set
# ebarbosa        | Not set
# Daniel-B-Kim    | Not set
# basireddy-m     | Not set
# Sushanth-Tanari | Not set
# Prince-Dewangan | Not set
# Ivan-Rodriguez-Garriga | Not set
# Samhitha-Pentaparthy | Not set
# Wxgsydprod      | Not set
# John-Yeo        | Not set
# Perry-Mills     | Not set
# vishvashah08    | Not set
# Robert-Kanter   | Not set
# Nikola-Plavjanikova | Not set
# Jakub-M-Truszkowski | Not set
# Ali-Bouali      | Not set
# Slawomir-Klimowski | Not set
# sanghugaurav    | Not set
# despoinakotsopoulou | Not set
# Natalia-Piekarz | Not set
# pawel-barket    | Not set
# Raul-Mendiratta | Not set
# joseAndres-estrada | Not set
# sumeshmageshbabu | Not set
# Nicholas-Stefanakis | Not set
# Shaobin-Ding    | Not set
# Khushboo-S      | Not set
# david-fernandes | Not set
# Pravallika-Anekalla | Not set
# fred-li         | Not set
# JOMON-JOSEPH2   | Not set
# Abhiram-S-L     | Not set
# Sruthi-M2       | Not set
# Arthi-Vijayaraghavan | Not set
# Tobias-Thiel    | Not set
# austin-joyal    | Not set
# Sricharan-B     | Not set
# Shawn-Cui       | Not set
# Maciej-Piotrowski1 | Not set
# Damian-Bakowski | Not set
# KARTHIKA-M-M    | Not set
# Manar           | Not set
# Nikki-Kumari    | Not set
# mkatari         | Not set
# Abhijeet-Pande  | Not set
# Minhas-A-V      | Not set
# Fscibuild       | Not set
# Aryan-Gupta3    | Not set
# Ashutosh-Kumar50 | Not set
# ajay-kr         | Not set
# Sophie-Murthy   | Not set
# na9patel        | Not set
# ade-banjo       | Not set
# Fernando-Vega-Valerio1 | Not set
# Glen-Wang       | Not set
# angelika-siwek  | Not set
# Piotr-Gnysinski1 | Not set
# Harshad-Nehate  | Not set
# Trupti-Divkar3  | Not set
# Szymon-Szarek1  | Not set
# Ariel-Solis-Bermudez1 | Not set
# dev-raj         | Not set
# Pavithradurga-B | Not set
# mayteandrea     | Not set
# Michael-Crampon | Not set
# katarzyna-nowogrodzka | Not set
# Michael-Moyles  | Not set
# Shiny-Micheal   | Not set
# Anjana-Ashok    | Not set
# Harshal-Bharre  | Not set
# narayansagar    | Not set
# Olivanan-Chandan | Not set
# Bartosz-Pawlowski | Not set
# Dora-Xiao       | Not set
# Kacper-Slusarczyk | Not set
# Konrad-Lapka    | Not set
# Lily-Akagbosu   | Not set
# Artur-Kornelski | Not set
# Joan-Sala-Reixach | Not set
# Nelson-B        | Not set
# Andres-Perez-Sanchez | Not set
# Jerzy-Pietruszewski | Not set
# sambacha        | Not set
# Yuliia-Smykova  | Not set
# Mohit-Tanwar2   | Not set
# Jakub-Grabowski | Not set
# chloelam        | Not set
# rbose           | Not set
# maciej-bonowicz | Not set
# Ashamol-Soman   | Not set
# Esha-Jain1      | Not set
# Vrushank-T      | Not set
# SHIVAJI-LAWARE  | Not set
# Piotr-Auksztulewicz | Not set
# Akash-Mondal2   | Not set
# Pratik-Swami    | Not set
# Varsha-Manikandan | Not set
# rudrapatel      | Not set
# Vishwaraj-Pawar | Not set
# tim-fuhrmann    | Not set
# Jakub-Grela     | Not set
# luca-walz       | Not set
# Dominika-Mazur  | Not set
# PRAGATHI-PRASHANTH | Not set
# Lakshmanan-P    | Not set
# luis-chaconc    | Not set
# Akshay-Morale1  | Not set
# srgayath        | Not set
# Bartlomiej-Lakuta | Not set
# Genai-funcid    | Not set
# Narkedamilli-Mounica | Not set
# Ossprestissimo  | Not set
# t-akinci        | Not set
# Danylo-Spichakov | Not set
# Igor-Siemek     | Not set
# sebastian-kosciolek | Not set
# pschwaja        | Not set
# Tomasz-Sarkowicz | Not set
# Paul-Baby1      | Not set
# Artemiy-Shipovalov | Not set
# Jakub-Klimek1   | Not set
# Marcin-Fortuna1 | Not set
# Srithika-R      | Not set
# ohmurphy        | Not set
# AndrewKim0515   | Not set
# Arko-Mitra      | Not set
# shantha-kumara-nijalingappa | Not set
# Sahana-Raghavendra | Not set
# Vaqif-Musadirov | Not set
# Konrad-Materek  | Not set
# Karina-Grakova  | Not set
# Rachel-Kwan     | Not set
# Zara-Kazi       | Not set
# Wojciech-Smajda | Not set
# Rameshbabu-Palanichamy | Not set
# Shubham-Singh   | Not set
# kuldeep-singh-partner | Not set
# Harshal-Bhoyar  | Not set
# Michael-Sevcik  | Not set
# ymak-ibm        | Not set
# filippa-osswald | Not set
# Milosz-Bogacz1  | Not set
# Andrii-Ivanov   | Not set
# krystof         | Not set
# Michal-Nawara   | Not set
# Pavel-Parizek   | Not set
# miktad          | Not set
# Ram-Koukuntla   | Not set
# Joanna-Gargas   | Not set
# Gargi-Pimplaskar1 | Not set
# Mungara-Hitesh1 | Not set
# Suhas-Harish    | Not set
# Shivani-S4      | Not set
# Jyoti1          | Not set
# Abhinav-Anand5  | Not set
# agnes-s         | Not set
# Kavya-Panicker  | Not set
# dora-hu         | Not set
# adhil           | Not set
# joel-jaison     | Not set
# nitish-ms       | Not set
# Najah           | Not set
# Ravi-Roshan     | Not set
# Sanjay-Balamurugan1 | Not set
# ishita-gupta    | Not set
# Srinithya-R-Padigela | Not set
# Gandharkulkarni | Not set
# Tomas-Kratochvil | Not set

# %%
text = '''
Ajiyos Yohannan
Ajiyos
Senior Manager - WatsonX Governance Factsheet Service, Data and AI
Channel Manager


Atul kumar Karn
Atul kumar Karn


Deirdre Moran
Deirdre Moran
Software Developer


femi aluko
femi
:palm_tree:
Software Developer


Harshit Gupta
harshit.gupta4


Jaswanth Pallavolu
jaswanth.pallavolu
Software Developer, Watsonx.gov


Jinu Shaji
Jinu Shaji
:face_with_thermometer:
Software Developer - WatsonX Governance


Joel Varghese
joevar
:vacation_upcoming:
Software Developer, Watsonx.Governance


Lakshmi Narayanan
Lakshmi
:spiral_calendar_pad:
Python(Data Science) developer


Laukesh Yadav
Laukesh


Puneet U(you)
puneetudhayan


Ranjana V
Ranjana
:spiral_calendar_pad:
Software Developer


Rohit Viswanath
Rohit
Software Engineer, Watsonx Governance, IBM Data & AI


Sanjay Balamurugan
Sanjay Balamurugan


Shaik Mohammed Irfan Saeed
Irfan Saeed
Software Developer, watsonx.governance


SHASHIDHAR Y
syellare
Software Engineer, Ai Governance, Factsheet


Shreya Narayanan
shreya.n


Shruti Nimgaonkar
snimgaonkar
:face_with_thermometer:
Software Developer


Shubham Kale
Shubham Kale
Software Developer - Watsonx Governance


Suhas Gowda Harish
Suhas Gowda Harish


Sumangala Palled
Sumangala Palled'''

# %%
all_collaborators[69]
# Out:
# {'login': 'kanellos',
#  'id': 4552,
#  'node_id': 'MDQ6VXNlcjQ1NTI=',
#  'avatar_url': 'https://avatars.github.ibm.com/u/4552?',
#  'gravatar_id': '',
#  'url': 'https://github.ibm.com/api/v3/users/kanellos',
#  'html_url': 'https://github.ibm.com/kanellos',
#  'followers_url': 'https://github.ibm.com/api/v3/users/kanellos/followers',
#  'following_url': 'https://github.ibm.com/api/v3/users/kanellos/following{/other_user}',
#  'gists_url': 'https://github.ibm.com/api/v3/users/kanellos/gists{/gist_id}',
#  'starred_url': 'https://github.ibm.com/api/v3/users/kanellos/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://github.ibm.com/api/v3/users/kanellos/subscriptions',
#  'organizations_url': 'https://github.ibm.com/api/v3/users/kanellos/orgs',
#  'repos_url': 'https://github.ibm.com/api/v3/users/kanellos/repos',
#  'events_url': 'https://github.ibm.com/api/v3/users/kanellos/events{/privacy}',
#  'received_events_url': 'https://github.ibm.com/api/v3/users/kanellos/received_events',
#  'type': 'User',
#  'user_view_type': 'public',
#  'site_admin': False,
#  'permissions': {'admin': False,
#   'maintain': True,
#   'push': True,
#   'triage': True,
#   'pull': True},
#  'role_name': 'maintain'}

# %%
factsheet_team = [i.strip().split('\n')[0] for i in text.split('\n\n')]

# %%
import re
from tqdm import tqdm

factsheet_team_info = []

def sanitize_for_matching(text):
  """Converts text to lowercase and removes all non-alphanumeric characters."""
  return re.sub(r'[^a-z]', '', text.lower())

for name in tqdm(factsheet_team):
  temp = {"displayName": name, "githubUsername": None}
  sanitized_name = sanitize_for_matching(name)
  
  for collaborator in all_collaborators:
    sanitized_login = sanitize_for_matching(collaborator['login'])
    
    # Check if the sanitized username is part of the sanitized display name
    if sanitized_login in sanitized_name:
      temp["githubUsername"] = collaborator['login']
      # Match found, no need to check other collaborators
      break
      
  factsheet_team_info.append(temp)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 21/21 [00:00<00:00, 833.77it/s]

# %%
import json
json.dumps(factsheet_team_info)
# Out:
# '[{"displayName": "Ajiyos Yohannan", "githubUsername": null}, {"displayName": "Atul kumar Karn", "githubUsername": null}, {"displayName": "Deirdre Moran", "githubUsername": "Deirdre-Moran"}, {"displayName": "femi aluko", "githubUsername": "femi"}, {"displayName": "Harshit Gupta", "githubUsername": "Harshit-Gupta4"}, {"displayName": "Jaswanth Pallavolu", "githubUsername": "jaswanth-pallavolu1"}, {"displayName": "Jinu Shaji", "githubUsername": "Jinu-Shaji"}, {"displayName": "Joel Varghese", "githubUsername": null}, {"displayName": "Lakshmi Narayanan", "githubUsername": "Lakshmi-Narayanan2"}, {"displayName": "Laukesh Yadav", "githubUsername": "Laukesh-Yadav"}, {"displayName": "Puneet U(you)", "githubUsername": "puneet"}, {"displayName": "Ranjana V", "githubUsername": "Ranjana-V"}, {"displayName": "Rohit Viswanath", "githubUsername": "rohit-viswanath"}, {"displayName": "Sanjay Balamurugan", "githubUsername": "Sanjay-Balamurugan1"}, {"displayName": "Shaik Mohammed Irfan Saeed", "githubUsername": "Shaik-Mohammed-Irfan-Saeed"}, {"displayName": "SHASHIDHAR Y", "githubUsername": null}, {"displayName": "Shreya Narayanan", "githubUsername": "Shreya-Narayanan"}, {"displayName": "Shruti Nimgaonkar", "githubUsername": null}, {"displayName": "Shubham Kale", "githubUsername": "Shubham-Kale"}, {"displayName": "Suhas Gowda Harish", "githubUsername": null}, {"displayName": "Sumangala Palled", "githubUsername": "Sumangala-Palled"}]'

# %%
factsheet_team_info
# Out:
# [{'displayName': 'Ajiyos Yohannan', 'githubUsername': None},
#  {'displayName': 'Atul kumar Karn', 'githubUsername': None},
#  {'displayName': 'Deirdre Moran', 'githubUsername': 'Deirdre-Moran'},
#  {'displayName': 'femi aluko', 'githubUsername': 'femi'},
#  {'displayName': 'Harshit Gupta', 'githubUsername': None},
#  {'displayName': 'Jaswanth Pallavolu', 'githubUsername': None},
#  {'displayName': 'Jinu Shaji', 'githubUsername': 'Jinu-Shaji'},
#  {'displayName': 'Joel Varghese', 'githubUsername': None},
#  {'displayName': 'Lakshmi Narayanan', 'githubUsername': None},
#  {'displayName': 'Laukesh Yadav', 'githubUsername': 'Laukesh-Yadav'},
#  {'displayName': 'Puneet U(you)', 'githubUsername': 'puneet'},
#  {'displayName': 'Ranjana V', 'githubUsername': 'Ranjana-V'},
#  {'displayName': 'Rohit Viswanath', 'githubUsername': 'rohit-viswanath'},
#  {'displayName': 'Sanjay Balamurugan', 'githubUsername': None},
#  {'displayName': 'Shaik Mohammed Irfan Saeed',
#   'githubUsername': 'Shaik-Mohammed-Irfan-Saeed'},
#  {'displayName': 'SHASHIDHAR Y', 'githubUsername': None},
#  {'displayName': 'Shreya Narayanan', 'githubUsername': 'Shreya-Narayanan'},
#  {'displayName': 'Shruti Nimgaonkar', 'githubUsername': None},
#  {'displayName': 'Shubham Kale', 'githubUsername': 'Shubham-Kale'},
#  {'displayName': 'Suhas Gowda Harish', 'githubUsername': None},
#  {'displayName': 'Sumangala Palled', 'githubUsername': 'Sumangala-Palled'}]

# %%
[i['login'] for i in all_collaborators if 'joe' in i['login']]
# Out:
# ['bentonyjoe', 'joe-veliyath', 'joel-jaison']
